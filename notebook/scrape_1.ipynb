# %% [markdown]
# # Character Dialogue Scraping
#
# ## Overview
# We are scraping more movie script data from the internet to enrich our dialogue dataset to get more reliable result for project-6.
#
# ## Steps
# 1. Checking the movies and characters we need to scrape, those are movies/characters that exist in the moral rating dataset but do not exist in the movie script dataset.
# 2. Scrape/download the dataset directly from the internet.
# 3. Check whether our dataset is large enough in order to get reliable results.

# %% [markdown]
# ## Step 1
#
# structured_data_full is a structured data (formatted for moral rating predictions) containing all the movies and characters that exist in both movie script and rating dataset.

# %%
import json
import os
import pandas as pd

# %%
with open('../data/structured_data.json', 'r') as f:
    # Structured data is a dictionary containing movies and characters data
    # that exist in both ratings and dialogue datasets.

    # This was processed in analysis_2.ipynb
    structured_data = json.load(f)

with open('../data/structured_data_full.json', 'r') as f:
    # This contains all the movies and characters that exist in both movies and ratings datasets
    # but only characters with at least 100 lines of dialogue. 

    # This was processed in explore_2.ipynb
    structured_data_full = json.load(f)

# %%
# Let's load the moral rating dataset

moral_ratings = pd.read_csv("../data/SWCPQ-Features-Survey-Dataset-November2023/scripts/aggregated-means.csv", sep = '\t')

# %%
moral_ratings.head()
# Out:
#   Unnamed: 0    F1    F2    F3    F4    F5    F6    F7    F8    F9  ...  F491  \
# 0      MLP/1  40.4  88.0  16.9  38.2  37.5  73.6  74.9  54.5  82.3  ...  84.5
# 1      MLP/2  70.1  56.0  31.6  80.5  59.9  76.3  15.0  35.7  20.2  ...  70.7
# 2      MLP/3  63.0  82.1  32.7  96.9  12.8  87.5  42.5  33.6   8.6  ...  60.0
# 3      MLP/4   3.6  92.4   5.2  87.9  34.7  70.7  72.9  89.5  60.0  ...  77.2
# 4      MLP/5  26.9  63.9  29.9  35.9  56.1  63.5  56.7  61.5  62.2  ...  50.3
#
#    F492  F493  F494  F495  F496  F497  F498  F499  F500
# 0  53.6  37.3  21.0  67.2  62.1  30.4  45.7  19.8  50.9
# 1  34.7  51.5  26.6  75.2  46.2  63.6  86.1  51.6  16.0
# 2  40.9  62.5  35.1  59.1  37.6  60.3  97.1  49.9  23.7
# 3  83.2   1.9  10.2  38.4   7.4  76.9  49.8  80.4  61.9
# 4  66.6  26.5  53.9  70.6  51.1  68.2  40.7  52.1  42.7
#
# [5 rows x 501 columns]

# %%
moral_ratings.shape

# We potentially will have 2000 characters to work with if we're able to use all of them
# Out:
# (2000, 501)

# %%
with open("../data/SWCPQ-Features-Survey-Dataset-November2023/scripts/subjects.json", 'r') as f:
    subjects = json.load(f)

# Extract movie names that are in the moral ratings dataset
movie_in_rating_data = [data["name"] for movie_code, data in subjects.items()]

# %%
movie_to_scrape = [movie for movie in movie_in_rating_data if movie not in structured_data]

# %%
print(movie_to_scrape)  # 244 movies to scrape
# Out:
# ['Game of Thrones', 'Harry Potter', 'The Office', 'Friends', 'The West Wing', 'LOST', 'The Wire', 'Avatar: The Last Airbender', 'Star Trek: Deep Space Nine', 'Pride and Prejudice', 'Marvel Cinematic Universe', 'The Simpsons', "That 70's Show", 'Downton Abbey', 'Grey&apos;s Anatomy', 'Breaking Bad', 'Firefly + Serenity', 'Lord of the Rings', 'Community', 'The Walking Dead', 'The Big Bang Theory', 'True Detective', 'Parks and Recreation', 'The Hunger Games', 'Westworld', 'Casablanca', 'Battlestar Galactica', 'Mad Men', 'Pirates of the Caribbean', 'Sherlock', 'Law & Order: SVU', 'Silicon Valley', 'Twin Peaks', 'The X-Files', 'Romeo and Juliet', 'Cowboy Bebop', 'Stargate SG-1', 'Mean Girls', 'Alien', 'Robin Hood', 'Orange is the New Black', 'Friday Night Lights', 'Atlas Shrugged', 'Brooklyn Nine-Nine', 'The Room', 'Seinfeld', 'Two and Half Men', 'NCIS', 'This Is Us', 'Arrested Development', 'Ozark', 'Scrubs', 'Star Trek: The Next Generation', 'Girls', 'Prison Break', 'The Mentalist', 'Desperate Housewives', 'The Good, the Bad, and the Ugly', 'Raiders of the Lost Ark', "Schitt's Creek", 'Glee', 'House, M.D.', 'The Good Place', 'Chilling Adventures of Sabrina', 'The 100', 'Scandal', 'How To Get Away With Murder', 'Riverdale', 'Space Force', 'Gossip Girl', 'Arrow', 'The Umbrella Academy', 'Hannibal', 'The Vampire Diaries', 'CSI: Crime Scene Investigation', 'Mr. Robot', 'The Flash', 'The Good Doctor', 'Veep', 'The Good Wife', 'Outer Banks', 'Mulan', 'Killing Eve', 'Castle', 'Damages', 'Boston Legal', 'Farscape', "Ocean's 11", 'The Sopranos', 'How I Met Your Mother', 'Lilo & Stitch', 'Gone With the Wind', 'Tommorrow Never Dies', 'Rick and Morty', '30 Rock', 'Unbreakable Kimmy Schmidt', 'Terminator 2: Judgement Day', 'Zombieland', 'Crazy Ex-Girlfriend', 'Hamilton', 'Mindhunter', 'Mad Max: Fury Road', 'Succession', 'Transformers', 'My Little Pony: Friendship Is Magic', 'South Park', 'New Girl', 'Les Mis&#xE9;rables', 'Gilmore Girls', 'Archer', 'Ghostbusters', 'The Devil Wears Prada', 'Lucifer', 'Yellowstone', 'The Fall', 'Pok&#xE9;mon', 'Sailor Moon', 'Vikings', 'Entourage', 'Bloodline', 'Supernatural', "Ender's Game", 'X-Men', 'Supergirl', 'Finding Nemo', 'The Little Mermaid', 'Snow White and the Seven Dwarfs', 'The Notebook', "It's Always Sunny in Philadelphia", 'Suits', 'Money Heist', 'Agents of S.H.I.E.L.D.', "The Handmaid's Tale", 'Once Upon a Time', 'Smallville', 'Outlander', 'Beauty and the Beast', "Dr. Horrible's Sing-Along Blog", 'Better Call Saul', 'Jane the Virgin', 'Gotham', 'Degrassi: The Next Generation', 'Sense8', 'Shameless', "Bob's Burgers", 'Fleabag', 'The Odyssey', 'Psych', 'White Collar', 'Bones', 'Calvin and Hobbes', 'Penny Arcade', 'The Americans', 'Stranger Things', 'The Man in the High Castle', 'Ctrl+Alt+Del', 'Modern Family', 'Dark', 'Criminal Minds', 'Peaky Blinders', 'Sons of Anarchy', 'Tropic Thunder', 'The Boys', 'Wynonna Earp', 'Futurama', 'Superstore', 'Elementary', 'Willy Wonka & the Chocolate Factory', 'Blue Bloods', 'Chicago Fire', 'Hamlet', 'The Blacklist', "The Queen's Gambit", 'Fifty Shades of Grey', 'Dirty Dancing', 'Elizabethtown', 'When Harry Met Sally...', 'Brokeback Mountain', 'ER', 'Cobra Kai', 'Broad City', 'Roman Holiday', '8 Mile', 'Portrait of a Lady on Fire', 'The Spectacular Now', "Breakfast at Tiffany's", 'Ruby Sparks', 'The Shape of Water', 'Moulin Rouge!', 'Normal People', 'Naruto', 'Am&#xE9;lie', 'Divergent', 'High School Musical', 'Ted Lasso', 'Sex Education', 'You', 'Squid Game', 'Euphoria', 'Locke & Key', 'Ferris Bueller&apos;s Day Off', 'Star Trek: Voyager', 'WandaVision', 'The Crown', 'Wheel of Time', 'Star Wars: The Last Jedi', 'Star Wars: Revenge of the Sith', 'Arcane', 'The Expanse', 'The Witcher', 'Shadow and Bone', 'A Series of Unfortunate Events', 'Emily in Paris', 'Pretty Little Liars', 'SpongeBob SquarePants', 'Death Note', 'Fullmetal Alchemist: Brotherhood', 'One Punch Man', 'Steins;Gate', 'Attack on Titan', 'Neon Genesis Evangelion', 'Yellowjackets', 'The Incredibles', ' ...

# %%
# Note that movies in new_dialogue are in format "Movie Name_Year"
# We need to extract the movie name from this format
def extract_movie_name(movie_key):
    """
    Extract the movie name from the movie key.
    
    :param movie_key: Movie key in the format "Movie Name_Year".
    :return: The movie name without the year.
    """
    return movie_key.rsplit('_', 1)[0]

# %%
from difflib import SequenceMatcher

def check_if_movie_exist(movie_name, data, threshold=90, discard_year = False) -> str:
    """
    Check if there's a movie in data that is similar to the given movie name.
    
    :param movie_name: Name of the movie to check.
    :param data: The data dictionary.
    :param threshold: Similarity threshold to consider a match (default is 90).
    :return: string of the movie name if a match is found, otherwise False.
    """
    for existing_movie in data.keys():
        if discard_year:
            existing_movie = extract_movie_name(existing_movie)
        similarity = SequenceMatcher(None, movie_name.lower(), existing_movie.lower()).ratio() * 100
        if similarity >= threshold:
            return existing_movie
    return ""

# %%
# Let's load both old and new script datasets

with open("../data/dialogue.json", 'r') as f:
    old_dialogue = json.load(f)

with open("../data/new_dialogue.json", 'r') as f:
    new_dialogue = json.load(f)

movies_in_new_dialogue = [extract_movie_name(movie_key) for movie_key in new_dialogue.keys()]

# %%
# Let's now check if there's movie in movie_to_scrape that exists in old_dialogue or new_dialogue

for movie in movie_to_scrape:
    if movie in old_dialogue:
        print(f"{movie} exists in old dialogue dataset")
    elif movie in new_dialogue:
        print(f"{movie} exists in new dialogue dataset")
    else:
        similar_movie = check_if_movie_exist(movie, old_dialogue, threshold = 80)
        if similar_movie:
            print(f"{movie} is similar to {similar_movie} in old dialogue dataset")
        else:
            similar_movie = check_if_movie_exist(movie, new_dialogue, threshold=80, discard_year=True)
            if similar_movie:
                print(f"{movie} is similar to {similar_movie} in new dialogue dataset")
            
            # We don't need to print if the movie is not found
            # else:
            #     print(f"{movie} does not exist in either dataset")
# Out:
# The West Wing is similar to The Sting in new dialogue dataset
# The Wire is similar to The Wife in new dialogue dataset
# Pride and Prejudice exists in old dialogue dataset
# Breaking Bad is similar to Breaking Away in old dialogue dataset
# Pirates of the Caribbean exists in old dialogue dataset
# Twin Peaks exists in old dialogue dataset
# The X-Files is similar to The X Files in new dialogue dataset
# Romeo and Juliet is similar to Romeo + Juliet in new dialogue dataset
# The Room is similar to The Prom in new dialogue dataset
# This Is Us is similar to This is 40 in old dialogue dataset
# Star Trek: The Next Generation is similar to Star Trek: Generations in old dialogue dataset
# Desperate Housewives is similar to Desperate Hours in new dialogue dataset
# Mulan exists in old dialogue dataset
# Killing Eve is similar to Killing Zoe in old dialogue dataset
# Tommorrow Never Dies is similar to Tomorrow Never Dies in old dialogue dataset
# Terminator 2: Judgement Day exists in old dialogue dataset
# Mindhunter is similar to Manhunter in old dialogue dataset
# South Park exists in old dialogue dataset
# New Girl is similar to Gone Girl in new dialogue dataset
# Les Mis&#xE9;rables is similar to Les Miserables in old dialogue dataset
# The Fall is similar to The Fly in new dialogue dataset
# Finding Nemo exists in old dialogue dataset
# Psych is similar to Psycho in old dialogue dataset
# The Americans is similar to The American in new dialogue dataset
# Tropic Thunder exists in old dialogue dataset
# The Boys is similar to The Abyss in new dialogue dataset
# Elementary is similar to Elemental in new dialogue dataset
# ER is similar to Her in old dialogue dataset
# Sex Education is similar to An Education in old dialogue dataset
# Ferris Bueller&apos;s Day Off is similar to Ferris Bueller's Day Off in old dialogue dataset
# The Crown is similar to The Town in new dialogue dataset
# Star Wars: Revenge of the Sith is similar to Star Wars: Episode III - Revenge of the Sith in new dialogue dataset
# Arcane is similar to Arcade in old dialogue dataset
# The Witcher is similar to The Hitcher in new dialogue dataset
# The Incredibles is similar to The Incredible Hulk in new dialogue dataset
# After Life is similar to After.Life in old dialogue dataset
# The OA is similar to The Lorax in new dialogue dataset

# %%
for subject, data in subjects.items():
    if data["name"] == "After Life":
        print(data.values())
# Out:
# dict_values([['Tony Johnson', 'AFTL/1.jpg'], ['Matt Braden', 'AFTL/2.jpg'], ['Lenny', 'AFTL/3.jpg'], ['Kath', 'AFTL/4.jpg'], ['Lisa Johnson', 'AFTL/5.jpg'], ['Emma', 'AFTL/6.jpg'], 6, 'After Life'])

# %% [markdown]
# 30 Potential additional movies (5 are potentially discarded)
#
# After manual checking, we're taking 27 out of these 30 movies (all except for Death Note, Romeo and Juliet, and Psych).

# %%
"The Notebook" in new_dialogue
# Out:
# False

# %%
# Below are movies we want to add to the structured_data

movies_to_add = [
    ["Pride and Prejudice", "old"],
    ["Pirates of the Caribbean", "old"],
    ["Twin Peaks", "old"],
    ["Mulan", "old"],
    [("Star Wars: Revenge of the Sith","Star Wars: Episode III - Revenge of the Sith"), "new" ],
    [("Ferris Bueller&apos;s", "Ferris Bueller's Day Off"), "old"],
    ["South Park", "old"],
    ["Tropic Thunder", "old"],
    ["Finding Nemo", "old"],
    ["Terminator 2: Judgement Day", "old"],
    ["Mindhunter", "old"],
    [("Les Mis&#xE9;rables", "Les Miserables"),"old"]
]

# %% [markdown]
# Let's define a function to insert the data for these movies easier.

# %%
def add_movies_to_structured_data(movies_to_add, structured_data, new_dialogue, old_dialogue, subjects, moral_ratings) -> dict:
    """
    Add movies to the structured_data dictionary.
    
    :param movies_to_add: List of movies to add.
    :param structured_data: The structured data dictionary.
    :param new_dialogue: New dialogue dataset.
    :param old_dialogue: Old dialogue dataset.
    :return: Updated structured_data dictionary.
    """
    for movie_info in movies_to_add:
        if isinstance(movie_info[0], tuple):
            movie_name_in_rating_data, movie_name_in_dialogue_data = movie_info[0]
        else:
            movie_name_in_rating_data = movie_info[0]
            movie_name_in_dialogue_data = movie_name_in_rating_data
        
        for subject, subject_data in subjects.items():
            if subject_data["name"] == movie_name_in_rating_data:
                movie_key = subject
                break
        else:
            print(f"Movie {movie_name_in_rating_data} not found in subjects.")
            continue

        dct = {
            "subject_name": movie_name_in_rating_data,
            "subject_code": movie_key,
            "characters": {}
        }
        # <TODO> Add logic to add characters for this movie
        structured_data[movie_info[1]] = dct
    
    return structured_data

# %%
movie = "Ghostbusters_1984"

for movie_name in subjects.values() :
    if movie_name["name"] == "Ghostbusters":
        print(movie_name)
# Out:
# {'1': ['Peter Venkman', 'GB/1.jpg'], '2': ['Ray Stantz', 'GB/2.jpg'], '3': ['Egon Spengler', 'GB/3.jpg'], '4': ['Dana Barrett', 'GB/4.jpg'], '5': ['Louis Tully', 'GB/5.jpg'], 'N': 5, 'name': 'Ghostbusters'}

# %%
for movie, movie_data in structured_data.items():
    if not movie_data["characters"]:
        print(f"Movie {movie} has no characters in structured_data")
# Out:
# Movie Alien has no characters in structured_data
# Movie Bones has no characters in structured_data
# Movie Casablanca has no characters in structured_data

# %%
structured_data["Superbad"]
# Out:
# {'subject_name': 'Superbad',
#  'subject_code': 'SB',
#  'characters': {'SETH': {'character_name': 'SETH',
#    'subject_name': 'Seth',
#    'subject_code': 'SB/1',
#    'rating': [29.4,
#     72.3,
#     50.6,
#     38.9,
#     73.6,
#     15.0,
#     54.8,
#     69.7,
#     74.3,
#     61.2,
#     55.5,
#     36.9,
#     85.3,
#     32.7,
#     85.1,
#     77.6,
#     24.2,
#     31.8,
#     32.1,
#     75.1,
#     34.7,
#     35.7,
#     74.0,
#     41.0,
#     65.4,
#     81.5,
#     17.3,
#     43.2,
#     32.7,
#     37.8,
#     24.4,
#     68.4,
#     14.8,
#     16.0,
#     20.4,
#     18.6,
#     29.7,
#     19.9,
#     46.8,
#     70.5,
#     74.6,
#     13.9,
#     74.3,
#     14.0,
#     42.0,
#     30.9,
#     32.9,
#     36.8,
#     78.3,
#     83.3,
#     77.6,
#     41.0,
#     52.9,
#     45.1,
#     62.9,
#     60.8,
#     24.1,
#     28.7,
#     22.6,
#     86.7,
#     66.1,
#     63.3,
#     63.0,
#     25.8,
#     63.8,
#     61.1,
#     19.7,
#     32.7,
#     76.6,
#     16.9,
#     77.4,
#     28.4,
#     25.3,
#     79.4,
#     16.9,
#     29.9,
#     14.9,
#     24.5,
#     21.5,
#     50.9,
#     69.6,
#     60.2,
#     78.5,
#     46.5,
#     41.2,
#     59.9,
#     32.5,
#     27.1,
#     28.3,
#     77.4,
#     45.8,
#     27.8,
#     53.5,
#     81.7,
#     15.0,
#     80.3,
#     65.7,
#     64.5,
#     68.7,
#     49.1,
#     20.3,
#     59.6,
#     57.6,
#     69.1,
#     35.7,
#     58.4,
#     56.0,
#     40.4,
#     56.9,
#     31.4,
#     58.9,
#     54.4,
#     54.4,
#     48.3,
#     19.2,
#     77.3,
#     45.8,
#     20.7,
#     37.8,
#     68.2,
#     18.2,
#     59.8,
#     66.7,
#     78.4,
#     49.8,
#     41.1,
#     38.6,
#     42.1,
#     46.7,
#     35.8,
#     71.8,
#     25.4,
#     24.5,
#     82.9,
#     72.5,
#     52.8,
#     47.7,
#     42.1,
#     55.5,
#     47.6,
#     70.4,
#     35.6,
#     22.3,
#     81.5,
#     64.1,
#     79.3,
#     81.1,
#     86.8,
#     70.0,
#     84.5,
#     42.2,
#     59.9,
#     27.0,
#     25.3,
#     68.9,
#     22.4,
#     80.2,
#     80.7,
#     57.8,
#     28.6,
#     41.9,
#     76.0,
#     78.7,
#     46.9,
#     22.8,
#     23.5,
#     77.2,
#     16.6,
#     24.8,
#     48.6,
#     54.9,
#     58.5,
#     15.5,
#     43.6,
#     19.6,
#     78.0,
#     44.7,
#     88.8,
#     34.0,
#     37.2,
#     74.5,
#     56.7,
#     59.9,
#     66.7,
#     41.1,
#     12.1,
#     28.4,
#     47.6,
#     54.2,
#     75.6,
#     69.1,
#     54.0,
#     48.2,
#     42.3,
#     73.0,
#     48.9,
#     75.9,
#     77.0,
#     84.9,
#     47.5,
#     24.9,
#     27.3,
#     71.8,
#     35.3,
#     31.5,
#     27.9,
#     67.6,
#     65.3,
#     34.5,
#     33.0,
#     29.0,
#     39.3,
#     87.9,
#     51.9,
#     65.0,
#     43.8,
#     57.9,
#     21.6,
#     28.3,
#     51.8,
#     72.1,
#     68.5,
#     59.9,
#     26.2,
#     74.4,
#     77.7,
#     52.4,
#     42.0,
#     70.3,
#     49.3,
#     68.3,
#     82.5,
#     76.9,
#     47.7,
#     68.1,
#     55.3,
#     31.5,
#     49.3,
#     43.3,
#     77.2,
#     44.2,
#     62.9,
#     37.2,
#     55.3,
#     44.2,
#     76.0,
#     68.0,
#     26.0,
#     41.6,
#     47.0,
#     72.3,
#     48.6,
#     73.9,
#     48.9,
#     39.0,
#     25.1,
#     38.6,
#     23.4,
#     73.5,
#     44.9,
#     76.3,
#     18.1,
#     78.3,
#     74.5,
#     71.4,
#     50.1,
#     27.5,
#     63.6,
#     11.8,
#     61.7,
#     81.5,
#     27.5,
#     46.7,
#     35.4,
#     68.1,
#     46.0,
#     54.4,
#     38.4,
#     64.8,
#     75.2,
#     25.7,
#     58.3,
#     52.8,
#     68.1,
#     49.6,
#     72.3,
#     67.1,
#     81.1,
#     37.5,
#     41.1,
#     60.2,
#     63.0,
#     64.3,
#     32.8,
#     80.5,
#     52.3,
#     28.6,
#     72.1,
#     75.1,
#     37.3,
#     74.5,
#     67.3,
#     41.9,
#     45.7,
#     60.9,
#     42.2,
#     48.8,
#     29.4,
#     52.3,
#     57.3,
#     23.7,
#     33.6,
#     42.4,
#     76.5,
#     45.2,
#     74.5,
#     61.1,
#     89.2,
#     73.2,
#     33.2,
#     83.9,
#     14.4,
#     31.6,
#     64.1,
#     18.5,
#     32.7,
#     25.2,
#     67.8,
#     52.2,
#     47.9,
#     25.9,
#     12.6,
#     51.3,
#     54.4,
#     67.7,
#     90.0,
#     73.4,
#     38.1,
#     20.3,
#     23.7,
#     59.2,
#     34.6,
#     55.4,
#     48.3,
#     75.7,
#     59.2,
#     16.8,
#     25.2,
#     79.8,
#     58.1,
#     21.4,
#     23.5,
#     52.4,
#     28.1,
#     31.7,
#     46.8,
#     86.3,
#     54.1,
#     77.5,
#     83.8,
#     38.4,
#     41.7,
#     43.6,
#     48.8,
#     31.5,
#     56.4,
#     73.8,
#     42.6,
#     47.2,
#     62.9,
#     37.8,
#     51.8,
#     65.2,
#     48.5,
#     55.3,
#     36.5,
#     52.4,
#     70.7,
#     79.5,
#     74.0,
#     61.7,
#     30.5,
#     31.1,
#     49.3,
#     47.7,
#     52.0,
#     44.0,
#     87.1,
#     48.8,
#     51.7,
#     74.7,
#     68.0,
#     56.5,
#     65.8,
#     64.8,
#     64.9,
#     36.2,
#     26.3,
#     35.2,
#     56.4,
#     22.6,
#     47.8,
#     52.3,
#     36.4,
#     16.4,
#     30.4,
#     34.8,
#     24.0,
#     86.6,
#     49.8,
#     60.0,
#     35.5,
#     67.1,
#     89.4,
#     66.9,
#     65.3,
#     33.7,
#     21.9,
#     60.9,
#     70.1,
#     77.7,
#     19.0,
#     28.7,
#     21.6,
#     12.2,
#     61.7,
#     33.1,
#     87.0,
#     45.1,
#     77.7,
#     50.2,
#     34.9,
#     69.8,
#     45.6,
#     66.3,
#     49.2,
#     28.6,
#     19.7,
#     41.6,
#     68.8,
#     28.0,
#     46.5,
#     64.6,
#     23.5,
#     45.5,
#     7.2,
#     43.3,
#     55.1,
#     75.0,
#     20.7,
#     16.2,
#     57.8,
#     11.7,
#     21.5,
#     80.8,
#     59.6,
#     25.2,
#     86.0,
#     80.4,
#     13.4,
#     31.6,
#     69.2,
#     57.1,
#     61.0,
#     51.8,
#     67.6,
#     68.5,
#     82.0,
#     30.1,
#     30.2,
#     75.0,
#     74.9,
#     41.1,
#     33.5,
#     53.9,
#     41.8,
#     64.0,
#     26.4,
#     64.3,
#     43.5,
#     71.5,
#     49.4,
#     52.9,
#     21.5,
#     31.0,
#     43.6,
#     65.9,
#     46.4,
#     84.3,
#     29.4,
#     31.2,
#     54.1,
#     24.3,
#     28.5,
#     64.3,
#     22.6,
#     40.1,
#     19.3,
#     86.0,
#     38.5],
#    'sentences': ['Yo.',
#     "I was doing research last night, for next year, and I think I'm gon na go with Bang Bus.",
#     "The one where they bang the chicks on the bus. Thirteen bucks a month. Total access, live Web Cam feed. The works. It'll be like I'm on the bus, banging them myself.",
#     'It shows up under a different name.',
#     "I hope. Bang Bus. That would n't look good. Maybe I should just pick the one with the least dirty sounding name.",
#     "I could tell my parents I'm doing a project on Rome and I have to research orgies.",
#     "Do n't touch that!",
#     "Yeah, you know. I got some other places. Good places. I think we'll be fine.",
#     "That's disgusting.",
#     'I am truly, truly jealous that you got to suck on those tits when you were a baby.',
#     "Fuck it. I'm a senior about to graduate. They should be suckin' my balls. It's the least they can do for stealing three years of my life.",
#     "Oh, yeah dude, I forgot to tell you. I knocked the fuckin' shit out of him in capture the flag last week.",
#     "They're like baby toes.",
#     "Sometimes I get boners so big I ca n't hide them. And then I get nervous and my heart starts pounding, and it all just, like, feeds my boner. It just becomes this. thing. that's attached to me. And it wo n't go away.",
#     "You know it's been, like, a year and a half since I've seen an actual human female nipple. Besides my mom's. I saw it last month, and it was sick.",
#     "Exactly. Too hot. That's what sucks.",
#     "And three quarters of a blowjob, But that was fuckin' it. It was the peak of my ass - gettin' career, and it happened way, way, way too early.",
#     "Exactly! If I'd built up to it, I'd probably at least be having steady sex with a mediocre - looking girl at this point. I honestly now see why Orson Welles ate his fat ass to death.",
#     "But the key is to be good at sex by the time you're in college. You do n't want girls to think you suck dick at fucking.",
#     "Are you joking, man? Let's see here. she dated Dan Remick, Matt Muir, Josh Corber and what's - his - face. All of those were cool guys. She's been hot way longer than you think. Why would she end her high school career with me?",
#     "Yeah, and he was a complete fucking loser. You're a step up from that. Which is why you should stop being a pussy and do her! You could nailthe shit out of her for, like, two months before you leave. That bitch looks like a good fucker.",
#     "What, you can talk about that bitch all day every single day, but I ca n't say one thing about her?",
#     "I did n't insult her! I said she looks like a good fucker! She looks like she can take a dick. That's a good thing. Some women pride themselves on their dick - taking abilities.",
#     'No.',
#     'I bitched out? You bitched out! You were across the street before I even realized what was going on.',
#     "That guy's such a douche bag.",
#     'This. is. bullshit.',
#     "Mrs. Grier, I joined this class because I thought I'd be cooking with a partner. It's not fair. She's never here. I do n't get twice the marks for doing all the work.",
#     'Look at Evan.',
#     "While I'm over in my unit, isolated and alone, eating my terrible - tasting food because I ca n't even properly mix ingredients by myself, I got ta look over at that.",
#     "I wash and dry. And that is B.S. I'm like a single mother.",
#     'Jules?',
#     "That's kind of a personal question.",
#     'Nothing. It was my attempt at humour.',
#     'Well, I would call that a success.',
#     'Marscampone. scamponee cheese? Is that some kind of new cheese or something?',
#     'Except blue cheese. That stuff is sick.',
#     "Well whoever `` they'' are, they can eat my dick.",
#     "I do n't know, probably nothing. Why?",
#     'Yeah. Sure. That sounds fun. I love parties.',
#     "Oh, uh. It's more of, like, a love - hate thing. Right now I love them, though. Uh. how do I do this?",
#     "Dude! She's havin' a fuckin' party.",
#     "Do n't tell Fogell about the party.",
#     "Like you'd know what to do with it.",
#     "Yeah, well I'll be at Junior college where the girls are half as smart, and thus twice as likely to blow me.",
#     "Nothing. Sorry. You'll just have to fingerbang yourself.",
#     "Dude! That's perfect, ` cause, Evan, did n't you just say that you heard about a party?",
#     'Shut up. Who cares? Just be happy he told. And hey! Now you can buy the booze.',
#     "Did you tell that nimrod you're not going to room with him?",
#     'You better, man. That guy is a poon - tang repellent.',
#     "We're getting a fake ID.",
#     'Nothing! Jesus.',
#     "We're not, like, dependent on each other.",
#     'I would do terrible things to get with Jules tonight. Terrible things.',
#     "Ah, Helen's a bitch.",
#     'Hell no! I hate her.',
#     "I was never going to tell you this story, because I knew that if you heard it you would never want to get with Helen, but over the last few weeks I've been having a hard time thinking of a reason not to. So, here it is. Helen and I went to elementary school together, right?",
#     "Well, in the third grade, I had. like. an odd problem. For some reason, I do n't know why, I used to have this thing. where I would. like, kinda. sit around all day and draw pictures of dicks.",
#     "I'd just sit there for hours on end drawing dicks. I do n't know what it was. I could n't touch the pen to paper without it drawing a penis.",
#     "No shit that's fucked up. Here I am this little kid who ca n't stop drawing dicks to save his life.",
#     'Just listen.',
#     'I was very secretive about this dick thing I had going, after all, even I thought I was a loon, lord knows what other people would have thought. So I would take all my dick drawings and stick them in this Muppet lunch - box I had.',
#     'So one day I was finishing up a picture of a real big and veiny bastard, when all of a sudden.',
#     'Well she fucking flipped. She started crying and shit. Ratted me out. The principle finds my cock - Muppet lunch - box, and he fucking flips.',
#     'It turns out the principle was some crazy religious guy and he thought I was possessed by some dick devil or something.',
#     "So, he calls my parents and they make me go to a psychologist who kept asking me all these dick questions. My parents would n't even let me eat dick - shaped foods for, like, months! No carrots, no Pop - sicles, no hot - dogs. You know how many fucking foods are shaped like dick?",
#     "I ca n't even stand to look at her punk face.",
#     "I'm going to go take a piss. Peace.",
#     'Hey. Here I am.',
#     'Yeah. Why? Should I not?',
#     "Very right. Right. I'm getting that.",
#     "Ummm. I do n't know. I. think. maybe.",
#     "Well, funny thing about my back. It's located on my cock.",
#     'Ha! Alright, sure. I can do that. What do you guys want?',
#     'Wow. I would never even think of doing something that nice.',
#     'Should I just get, like, a shitload of different shit?',
#     "Yeah! I'll see you!",
#     'Man, just - Evan, listen to me. You know Jules? You know what she just did? She came up to me and asked me if I would buy her alcohol. Not just her, her whole party. Do you know what that means? It means that by some miracle, we were paired up, we talked, and she actually thought of me afterwards. Thought of me enough to decide that I was the guy that she was going to trust the fun - ness of her party with. She wants me! She fucking wants my dick!',
#     'Of course I thought of that! LISTEN TO THIS!',
#     'She has an older brother! She could have asked him, but she asked me! She looked me straight in the face and asked me. She wants to fuck me, man. Do you understand that? Fucking! Today is the day that fucking has become possible.',
#     "She's going to be at the party, she's gon na be drunk, and she likes me at least a little, so I can get with her. Then, I make her my girlfriend, and then I fuck her all summer long! Then, by the time college rolls around, I'm the fuckin' fucking master, man!",
#     "Once I've gotten with her, I write her love letters, flowers, I'll do anything - I'll be the most pussy - whipped guy in the universe - what chick would n't go out with a guy like that?",
#     "Fuck off, Greg. Why do n't you piss your pants again?",
#     'Wan na hear the best part?',
#     'Helen!',
#     "You do the same thing, man! Buy Helen her alcohol. Then, tonight, when you guys are both drunk, get with her! This is the last party we're ever going to go to as high school people! I've fully ignored my hatred for Helen in coming up with this, which is a big ass deal. We need to stop being pussy and for once just goes balls out, man!",
#     "Of course! It'll be pimp, and then you know she'll be drunk.",
#     "You talk to Helen, I'll find that retard Fogell.",
#     "That douche bag is n't back yet, I've been standing here with my thumb up my ass.",
#     "Whoa. That is fucking pimp. Why did n't I do that? Shit.",
#     "That's what we get for trusting a mental midget! He's fucking it all up! I bet he pussied out, just like I said he would!",
#     "I mean, what are we going to tell the girls? `` Sorry, we could n't do what we promised because we're dickless incompetents!'' We'll never get laid because of that little ass - fuck. How did he get in to State?! He's got shit for brains! Shit! How else can we get liquor?",
#     'Yeah! You almost gave me a goddamn heart attack! You better fucking have it, where is it?',
#     'So you picked McLovin?',
#     "Why was it between that or Muhammad? Why did n't you just pick a common name?",
#     "No! That's why you picked a bad name.",
#     "Look at this shit man, you do n't even have a first name. It just says `` NAME : MCLOVIN''",
#     "Holy shit! I do n't believe this. This says you're fucking 25! Why did n't you just put 21?",
#     'Fool!',
#     "You're not McLovin. No one's McLovin and this is never going to work. We need a new way to get alcohol. Could we drive to Canada or something?",
#     "What the fuck? Where's my car?",
#     'Shut up, Fogell.',
#     'I am aware of that, Fagell.',
#     "Let's go to your house.",
#     "Now we wait for your Mom to piss off and steal your parents' booze like your brother always does. Take a bit from every bottle. Piece of cake. It's not exactly what Jules wanted, but it'll do, right?",
#     "I told you I ca n't do that. I ca n't let Jules see me in the same shit I wore at school. It's completely unbecoming.",
#     "You're stupid! I ca n't go home. Then my mom will know the car got towed and I'll be grounded tonight. I'll just stay here all weekend and pick it up on Monday.",
#     "Do n't you have bigger clothes?",
#     'Not bad, eh?',
#     "Alright, here's what we'll do. I'll fuck your Mom in the basement while you steal the liquor.",
#     'Alright, dude. Get ready to receive.',
#     'What do you mean they. oh, man! Your parents are fuckers. What do we do now?',
#     "It's the biggest bottle, you douche. Just do it! She's right in the other room!",
#     'But, the booze?',
#     "Look at this mother. Smell it's glory.",
#     "Mmm. It's good. Barely a scent.",
#     "See that? I always said I had the highest alcohol tolerance. I'm like Superman.",
#     'Water?',
#     'Fuck. Your brother beat us to the punch. We have to go back!',
#     "Well, fuck. fine. Text your brother he's a stupid piece of crap.",
#     'What the hell is that?',
#     "You're gon na look like a Pinocchio.",
#     "You know, they got a ton of liquor right in there. If we get it now we can get to the party faster with all of Jules' shit.",
#     "Nobody said anything about you, dick - mouth. You have one name on your ID. It's out of the equation! And now I'm gon na have to take drastic measures. I'm gon na steal the booze.",
#     "That's right. And that way I give Jules back her money, like you did with Helen. That was good thinking, that's fucking pimp. That's how you seal a deal. It wo n't be hard. Remember Dan Vertlieb stole a keg from here and he's got, like, really bad scoliosis!",
#     "I'm stepping up. And once I'm up, I do n't step back down. Maybe you `` State'' boys do n't understand that.",
#     'Hope piggy can run.',
#     'Twenty two.',
#     'Thank you kindly.',
#     "Excuse me, ma'am. You dropped your purse. Would you like me to help you to your car?",
#     'That would be lovely!',
#     'Enjoy your remaining years!',
#     'I never had a choice.',
#     "Fuck you! I was gon na do it, but security was tight as shit. I was gon na do it though, do n't think I was n't. Let's go to the liquor store and try your stupid ID.",
#     "Here's the list.",
#     "We're getting girls their booze so they'll get with us. I put a lot of thought into that list. It's the perfect party bar, so do n't mess it up and get Sambuca again.",
#     "Oh yeah, and Mike's Hard Lemonade.",
#     'What the hell are you doing?',
#     'What are you talking about? You just promised you would. What is this shit?',
#     "Then we're in the same place that we're in right now!",
#     'This whole thing is bigger than you, asshead! Just go in there and buy the damn alcohol!',
#     "Then I will kill you! How's that? If you do n't buy the alcohol, I will kill you!",
#     'Then I will kill you, cut off your ugly face, put it over mine, and buy it my fucking self.',
#     "It's a good ID, right? Mike Snider never had a problem. It's fine. Right?",
#     'You brought a condom?',
#     "You asshole! You laughed in my face when I said we'd be having sex tonight.",
#     "No. That was n't the plan! We had a plan! I ca n't believe you did that without even consulting me about it!",
#     "I'm gon na go down on her for, like, hours. She'll love that. She'll want to go out with that.",
#     "And one little bottle of spermicidal lube. That's nuts. You ca n't let her know you brought that! These girls are 18, not dried up old ladies. They're ready to go.",
#     "Holy Shit! It's Cary Hutchins!",
#     'She had the biggest tits in the universe.',
#     "I got ta see these bastards. Let's check ` em out.",
#     "Man, I'm gon na pretend to trip and grab ` em.",
#     "I hope they've healed.",
#     'But she fully looked way better before. I thought when they reduced them, they just kind of reshaped them nicer. Made them more supple.',
#     "It's like me making my nuts saggier.",
#     'What?',
#     "I do n't believe this bullshit! I ca n't. this is n't happening! I did n't even know you could get arrested for this shit! WE NEED THAT FUCKING LIQUOR!",
#     "Fuck Fogell! He got arrested! We're on our own. We need a new way of getting liquor.",
#     'AAAHHH! The money! Fuck! Fuck! Fuck! How much money can you get?',
#     "That does n't matter anymore. I just lost a hundred dollars of Jules' money!",
#     "Help him? What are we gon na do? Bust him out of jail? I do n't even know where jail is! What we need is the alcohol, which is impossible because we do n't have any fucking money!",
#     'Fuck thinking! We need to act!',
#     "Why would n't I report you?",
#     'You have any money?',
#     "What is this? This is n't enough.",
#     'Well, you just came from the liquor store, give us your liquor.',
#     "Well, they'll be arresting somebody else if you do n't do something quick. Ow! My shoulder! It's killing me.",
#     'You better.',
#     "What? Jules' money is gone, Fogell's out, we've got no other option. Let's go.",
#     "He's an idiot. And he's our only hope. Come on, do n't break your promise to Helen.",
#     'Aaah!',
#     '875 - 6611?',
#     'Holy shit.',
#     "Jules! What's the haps?",
#     "Jules! I just got in a cab and I'm going to the liquor store as we speak.",
#     'Really?',
#     "Well, if they want to do that they're going to have to get through me.",
#     "She called, man! That's insane! She's practically begging for it. She said, `` I ca n't wait for you to get here.''",
#     'Whatever. Just act casual. And old. All we got ta do is find the booze and haul ass out of here.',
#     "Holy shit! Let's grab one of these buckets and go.",
#     "Why? Come on, we're here. Let's just hurry up and do this.",
#     'We need this liquor!',
#     "Then why have n't you ever made a move, you pussy?",
#     "These are n't girls, they're women! They need our dicks as much as we need their poons - and we all love liquor, so where's the fucking beef?!",
#     "You're really gon na bail on me?!",
#     "Okay, okay. if that's how you're going to be, then I'll get the booze on my own. And you're not getting any. And neither is Helen!",
#     'Hey, wut up?',
#     "Uh. no. What? I do n't know what you're talking about.",
#     "I did n't spill anything on myself.",
#     'Oh shit.',
#     'What the hell is this?',
#     'Yeah, so?',
#     'Why would I get blood on my leg from -.',
#     'OH SHIT!',
#     'Some girl perioded on my fucking leg!',
#     'That is disgusting.',
#     "Who's Bill? Do n't show Bill! No! I ca n't believe this is happening!",
#     'This is un - fucking - believable. I have to look good tonight!',
#     "Who gives a shit? Fuck! These are n't even my pants!",
#     "Yeah. It's really funny, huh? Yuk it up, assholes.",
#     'I got ta clean this shit.',
#     "Jesus's tits!",
#     'I did it man. Peace out - tro.',
#     "Hey! You got one, too! We're blood brothers.",
#     "I. I did n't dance with her! I do n't even dance! Never even tried it!",
#     "I do n't know. Maybe me and you rubbed up against each other at some point. How am I supposed to know?",
#     "I swear to God it was n't me!",
#     "It's nothing. It's detergent.",
#     'I. uh, I got blood on my pants.',
#     'I brought them from home.',
#     'AHH!',
#     "You're the one who used my leg as a tampon!",
#     ". huff. hufff. you fuckin' prick.",
#     'You. huff. bailed on me. huff. man.',
#     "Of course you did! We were supposed to do something and you left instead of doing it! That's the definition of bailing!",
#     'It is bailing, if you promised to burn your dick off!',
#     "The bottom line is you're a bailer. You just bailed on me, you bailed on me this morning when Terry spat on me, and you're bailing on me next year!",
#     'We were supposed to go to college together! Since elementary school! What ever happened to that!',
#     'I was not too stupid, I was too lazy!',
#     "Getting with a girl wo n't make you any less of a loser next year!",
#     "I did n't push you into fucking oncoming traffic!",
#     "We're great.",
#     'What, when cops drive like maniacs and hop the fucking curb?',
#     'Umm, no sir, detergent.',
#     'My clothes are dirty.',
#     'Ow!',
#     'ARGGG!',
#     'Jesus!',
#     'Fucking run!',
#     'No! Fuck off! You already drank our detergent beer!',
#     "Back off, or we'll kick the shit out of you!",
#     "So? Who cares? Just because he does n't have a home does n't mean he can be a lunatic!",
#     "What's the difference? I thought you did n't need it anyways. I thought you were just going to tell her how you feel, you fucking pussy.",
#     "Shut up, Fogell. Never mind. Evan'll tell you next year.",
#     'Told me what?',
#     'Just say it!',
#     "Save that shit for later. We've got shit to do.",
#     'The bar is open!',
#     'Sorry it was late.',
#     "I'll be right here.",
#     'To Jules!',
#     'Seth!',
#     "Hey! Let's do another one to me!",
#     'Jules! The hostess with the most - est! The woman of the hour!',
#     "This party's blowin' my ass off! I want you to have a drink with me.",
#     "It's just how I roll, Jules. No problems, no problems.",
#     "Uh. you know. I love talking, and conversing with you, you're so good at it, but I ca n't hear you. Could we just go on the. uh. balcony or something?",
#     "What? What's wrong?",
#     "But. there is no other time. School's up! This is the only time. what's wrong with now?",
#     'So? So are you.',
#     "You do n't drink? But. but, you told me to get the liquor!",
#     "You do n't drink!?!",
#     "And you, do n't want to. uh, you know.",
#     'Ahhh. man. fuck.',
#     "No! Yeah, so what if I am? I'm a fucking idiot and it was my last chance! So I should be crying.",
#     "To make you my girlfriend for the summer, okay? There! You're, like, the coolest person that's ever talked to me, and I thought we'd both be drunk, but.",
#     "` Cause you'd never get with me in your right mind! Look at me!",
#     'And now look at you!',
#     'help me.',
#     'sorry.',
#     'Oh no.',
#     'Evan.',
#     "No. I'm helping you, man! Just listen.",
#     "That's what I've been! Here.",
#     'I totally did! I wanted to!',
#     'Yeah! Sleepover! Fuckin. you got pizza bagels still?',
#     'Nice!',
#     "I ca n't believe she said that shit.",
#     "I fucking love you, too, man! I'm not embarrassed, I just love you!",
#     'I missed you, too. Come here, man.',
#     "We'll always be friends. ` Cause we love each other.",
#     "Like, three weeks ago I was in you room and, like, you were taking a dump and. I saw your residence placement thingy. I totally saw you're living with Fogell. So, like -",
#     "Do n't be! Do n't be! I'm sorry. I was being a bitch.",
#     "You know. I was pissed off I did n't get with Jules, but, like. we really got through a lot of our shit, you know?",
#     'Night, Evan. Love you, man.',
#     'Uh. morning.',
#     'Yeah. This is a really good pillow.',
#     'Maybe I should get going.',
#     'Oh. do you want to hang out? I was. gon na go to the mall, actually.',
#     "Yeah. That'd be nice. I'd really like that.",
#     "Well, I need someone's opinion.",
#     "Yeah, but when I was wearing your dad's pants last night I realized that if I buy pants that are too small it'll encourage me to lose weight. And in tight pants chicks'll kind of see my dick a little.",
#     "These pants suck. Let's the get the fuck out of here.",
#     'Is that them?',
#     "Fuck that, man. I ca n't talk to her, look what I did to her!",
#     'Jules. Helen. Hi.',
#     "Oh my god. I'm so sorry, Jules.",
#     "That looks terrible. No! I mean, it does n't look terrible, it looks -",
#     "Not really. I remember looking up, and you screaming at me. That's about it.",
#     "But seriously, I acted like a fuckin' idiot last night. I'm really sorry, you did n't deserve that.",
#     'You look good with a black eye.',
#     'Oh man.',
#     "Yes! Definitely. I'd love to. I had such bad acne last year, I became an expert on the stuff.",
#     'Yeah, but wait. you drove me here, Evan drove me here, how do we -',
#     "So, uh, I'll call you later."]},
#   'EVAN': {'character_name': 'EVAN',
#    'subject_name': 'Evan',
#    'subject_code': 'SB/2',
#    'rating': [71.5,
#     19.0,
#     60.4,
#     63.0,
#     81.0,
#     61.7,
#     14.1,
#     44.2,
#     29.4,
#     44.2,
#     19.5,
#     72.1,
#     45.5,
#     71.0,
#     24.1,
#     66.0,
#     78.9,
#     17.8,
#     77.1,
#     77.2,
#     41.0,
#     86.0,
#     19.1,
#     86.7,
#     21.6,
#     46.9,
#     83.3,
#     24.1,
#     65.7,
#     40.0,
#     82.5,
#     27.0,
#     51.7,
#     71.6,
#     56.7,
#     50.2,
#     63.7,
#     77.0,
#     25.6,
#     43.9,
#     29.2,
#     71.7,
#     58.8,
#     62.8,
#     82.5,
#     45.7,
#     75.3,
#     52.4,
#     20.5,
#     26.9,
#     24.1,
#     73.6,
#     60.0,
#     73.3,
#     26.8,
#     77.7,
#     80.5,
#     83.1,
#     77.3,
#     15.6,
#     51.9,
#     83.9,
#     25.9,
#     71.7,
#     56.6,
#     25.6,
#     80.7,
#     35.9,
#     33.4,
#     19.8,
#     41.5,
#     83.7,
#     56.2,
#     85.2,
#     70.5,
#     69.6,
#     6.3,
#     51.1,
#     65.5,
#     50.5,
#     21.1,
#     19.1,
#     34.1,
#     85.6,
#     72.2,
#     35.9,
#     50.0,
#     28.7,
#     82.9,
#     28.9,
#     69.3,
#     14.4,
#     59.3,
#     71.4,
#     35.8,
#     25.0,
#     54.1,
#     86.1,
#     48.2,
#     69.3,
#     47.4,
#     30.6,
#     52.2,
#     45.7,
#     83.1,
#     38.1,
#     63.8,
#     58.3,
#     68.9,
#     74.1,
#     34.8,
#     63.1,
#     65.5,
#     44.2,
#     67.2,
#     56.3,
#     43.2,
#     53.5,
#     72.1,
#     46.8,
#     62.6,
#     17.1,
#     90.3,
#     21.5,
#     68.1,
#     49.3,
#     17.0,
#     24.6,
#     32.6,
#     82.6,
#     54.5,
#     74.3,
#     70.8,
#     26.9,
#     39.3,
#     62.9,
#     43.4,
#     46.6,
#     83.4,
#     54.6,
#     82.9,
#     57.3,
#     71.8,
#     55.3,
#     21.2,
#     76.4,
#     43.8,
#     14.7,
#     36.4,
#     23.8,
#     61.4,
#     51.0,
#     53.5,
#     54.3,
#     24.1,
#     70.2,
#     39.8,
#     25.0,
#     68.6,
#     51.8,
#     76.1,
#     73.6,
#     66.3,
#     43.1,
#     65.9,
#     80.3,
#     37.6,
#     79.1,
#     49.1,
#     18.5,
#     49.7,
#     45.7,
#     51.3,
#     27.8,
#     37.7,
#     60.2,
#     30.2,
#     36.3,
#     77.6,
#     65.9,
#     63.5,
#     77.2,
#     84.7,
#     42.5,
#     27.7,
#     54.5,
#     68.2,
#     58.8,
#     48.2,
#     66.6,
#     36.0,
#     34.1,
#     45.5,
#     70.4,
#     29.0,
#     50.4,
#     43.8,
#     33.4,
#     32.5,
#     50.2,
#     71.8,
#     72.5,
#     80.4,
#     30.4,
#     24.5,
#     78.1,
#     55.2,
#     30.2,
#     43.1,
#     41.7,
#     51.0,
#     76.3,
#     31.4,
#     48.4,
#     31.6,
#     35.8,
#     41.5,
#     40.9,
#     51.9,
#     40.8,
#     36.5,
#     21.4,
#     60.2,
#     59.1,
#     54.5,
#     32.0,
#     82.3,
#     62.7,
#     40.5,
#     59.9,
#     35.1,
#     26.5,
#     42.1,
#     69.6,
#     46.0,
#     37.2,
#     65.5,
#     47.9,
#     70.3,
#     52.6,
#     65.4,
#     27.1,
#     69.1,
#     87.1,
#     57.9,
#     24.5,
#     27.8,
#     78.3,
#     33.6,
#     71.1,
#     40.7,
#     54.2,
#     53.5,
#     12.8,
#     55.2,
#     67.1,
#     41.7,
#     58.9,
#     81.8,
#     29.3,
#     34.2,
#     65.7,
#     77.2,
#     80.0,
#     54.8,
#     40.2,
#     57.9,
#     43.9,
#     61.6,
#     36.8,
#     65.0,
#     69.8,
#     42.0,
#     38.6,
#     70.8,
#     79.9,
#     28.3,
#     34.5,
#     73.5,
#     64.4,
#     30.4,
#     69.2,
#     67.4,
#     69.3,
#     56.6,
#     25.1,
#     26.5,
#     58.4,
#     25.5,
#     71.0,
#     35.4,
#     66.9,
#     36.2,
#     71.9,
#     40.8,
#     26.4,
#     72.2,
#     46.2,
#     44.6,
#     48.8,
#     43.1,
#     53.5,
#     78.9,
#     78.9,
#     68.9,
#     64.6,
#     41.6,
#     49.6,
#     16.4,
#     88.6,
#     64.5,
#     58.5,
#     65.9,
#     48.1,
#     62.8,
#     30.6,
#     76.3,
#     34.3,
#     42.7,
#     43.9,
#     41.9,
#     77.0,
#     69.7,
#     62.1,
#     17.7,
#     63.9,
#     55.1,
#     64.1,
#     49.5,
#     43.9,
#     43.8,
#     59.1,
#     51.4,
#     32.2,
#     86.6,
#     26.9,
#     22.6,
#     48.6,
#     65.0,
#     75.2,
#     63.4,
#     81.8,
#     49.2,
#     16.8,
#     37.0,
#     57.5,
#     24.9,
#     49.5,
#     20.0,
#     33.8,
#     71.3,
#     69.6,
#     75.2,
#     66.0,
#     68.9,
#     64.5,
#     44.9,
#     35.1,
#     61.1,
#     21.9,
#     38.3,
#     57.4,
#     23.5,
#     29.4,
#     59.5,
#     51.1,
#     70.2,
#     65.4,
#     81.9,
#     36.1,
#     19.6,
#     47.9,
#     58.6,
#     83.7,
#     20.1,
#     28.5,
#     46.3,
#     27.7,
#     80.5,
#     87.2,
#     77.8,
#     52.4,
#     64.6,
#     55.7,
#     47.4,
#     34.6,
#     73.9,
#     38.2,
#     19.8,
#     42.6,
#     10.3,
#     52.5,
#     24.4,
#     67.5,
#     26.0,
#     27.1,
#     49.8,
#     59.9,
#     43.2,
#     75.1,
#     39.4,
#     67.0,
#     81.1,
#     22.1,
#     84.3,
#     72.6,
#     66.1,
#     36.9,
#     57.6,
#     78.7,
#     45.8,
#     76.1,
#     63.6,
#     41.3,
#     52.5,
#     53.8,
#     22.8,
#     86.0,
#     51.5,
#     28.0,
#     23.4,
#     41.3,
#     51.8,
#     64.5,
#     28.7,
#     15.8,
#     67.5,
#     14.3,
#     49.4,
#     63.6,
#     24.9,
#     58.1,
#     23.5,
#     62.5,
#     41.6,
#     50.6,
#     66.3,
#     41.6,
#     78.1,
#     33.6,
#     33.1,
#     62.0,
#     53.8,
#     89.4,
#     70.0,
#     70.9,
#     79.8,
#     60.1,
#     80.4,
#     64.4,
#     29.8,
#     64.6,
#     76.3,
#     51.8,
#     85.4,
#     64.6,
#     59.7,
#     37.8,
#     44.9,
#     82.5,
#     41.3,
#     30.9,
#     41.1,
#     81.7,
#     82.3,
#     15.3,
#     38.2,
#     35.3,
#     68.3,
#     81.0,
#     81.8,
#     30.8,
#     61.9,
#     59.3,
#     79.0,
#     60.2,
#     33.0,
#     51.7,
#     79.9,
#     58.2,
#     55.7,
#     41.4,
#     16.3,
#     52.0,
#     78.9,
#     80.1,
#     41.4,
#     11.9,
#     19.4,
#     80.1,
#     26.5,
#     29.3,
#     74.6,
#     60.4,
#     72.8,
#     78.5,
#     55.0,
#     84.6,
#     21.7,
#     13.8],
#    'sentences': ["What's up?",
#     "Which one's Bang Bus?",
#     "That stuff's bullshit, they're all faking it. And plus, your parents are gon na look at the bill.",
#     "Weapons of Ass Destruction's out then.",
#     'Yeah. Just tell them your taking a class on blow jobs.',
#     'Miss each other? No!',
#     'Fuck you, man.',
#     "You're being an idiot, man. You really should n't park there.",
#     "What the hell's wrong with Dimitri?",
#     "Good! 9th Grade Camp he gave me whiplash in `` King of the Ring.'' I fucking hate that guy.",
#     'Look at those nipples.',
#     "It's not fair. I have to hide every erection I get.",
#     "Just imagine if girls were n't weirded out by our boners and they actually wanted to see ` em, like this shit.",
#     'Holy shit. Liat was two years ago? I guess so. She was insanely hot, though.',
#     "How can that possibly suck? I'd be fuckin' psyched if I'd gotten with a girl that hot. You got, like, two dozen handjobs!",
#     "You're like Orson Welles.",
#     "You'll have sex in college. Everyone does. And if not, you'll have the Bang Bus.",
#     "I still think you've got a chance with Jules. She got mad hot over last summer, and clearly has n't realized it, ` cause she still flirts with you.",
#     'Well, Helen got with Ariel Shafir.',
#     "Hey! I'm sick of you talking about her like that, man!",
#     "I do n't constantly insult her.",
#     'Wow. You really bitched out on that one.',
#     "Oh, do n't worry, no worries. Just keep it. Then you'll just have it, and you wo n't have to borrow another pen.",
#     "Yeah, it's a maybe. But, you know, I got ta, I got my. there's so much other fun shit that is going to be going on that night. so, you know.",
#     "Because of all the other fun shit I'm off doing.",
#     "Dimitri's? I uh. did n't want to go, because, well, I did other stuff. Saturday.",
#     'Oh yeah! Saturday night was awesome!',
#     'First my parents went out to a double feature, so a bunch of people came over.',
#     'and we had a couple drinks in my basement.',
#     "and Seth's parents were having this cocktail party, and we went over there to, like, mingle.",
#     'and there were actually some really interesting and, like, entertaining people there.',
#     'and, uh, then we saw some, uh, live music.',
#     'then we went to a club downtown.',
#     'and then we pretty much called it a night and went home.',
#     "you would've loved it.",
#     'Yeah. well, you know, me and Seth are always cooking up. uh. fun little. events.',
#     'Nah. We were going to but, uh, we got into different ones.',
#     "Same shit I've always been doing. It'll be fine. Do n't worry about it. I'm not.",
#     "That's good shit. Huh, Miroki?",
#     'What you doing?',
#     "Well done, man. We'll see you after class.",
#     'Uh. no, not yet.',
#     "Actually, we're going to different schools.",
#     "Yeah? What do people think is gon na happen? That's what I do n't get.",
#     "We met when we were 8, we were fine before then. It's not like we do everything together.",
#     'So it looks like we get a little graduation party after all.',
#     "No shit. I'd give my left foot to start dating Helen. She's killin' me.",
#     "I'm fuckin' sick of this shit, man! Seriously. Why do you hate her? Is there even an actual reason? Because seriously, I'm beginning you think you like her.",
#     'Why?',
#     'What?',
#     "That's fucked.",
#     'What does that have to do with Helen?',
#     "You hit Helen's foot with your dick?",
#     "Wow. That's really messed up.",
#     "Did you ever think maybe she's just using you to get her alcohol?",
#     "Are you stupid? You're not going to be able to sleep with her tonight.",
#     "Make her your girlfriend? Of course! That's good. So, hypnosis, love potion, or mind - control helmet?",
#     "Oh, I have n't?",
#     'I should get Helen alcohol?',
#     'Have you talked to Fogell?',
#     'Hey Helen! Hold up. Did you hear about the party tonight?',
#     "No, no, I am. That's why I came looking for you. Me and some guys are going to the liquor store after class, so I was thinking I could buy you yours, if you needed someone to.",
#     "You will absolutely not. It's my treat.",
#     "I'm sorry! Shit, shit. I'm so sorry! I just wanted to give you a friendly nudge in the arm, you know? I'm so sorry.",
#     "Yeah. I'll see you then. I'm so sorry about that.",
#     'I did it, dude. I even offered to pay for it. It was pimp.',
#     'Where have you been?',
#     "Okay Mr. `` McLovin''? What kind of a stupid name is that? What are you trying to be, an Irish R&amp;B singer?",
#     'Have you ever actually met a guy named Muhammad?',
#     'You probably have federal agents tracking you for even considering the name Muhammad on a fake ID!',
#     'One name?',
#     'Under what circumstances would you ever have to show a chick your ID?',
#     "Calm down! It's not terrible! This might work, but it's up to you, Fogell. They'll either think, `` Oh, it's another punk kid with a fake ID.'' Or, `` Look, it's McLovin, the twenty five year - old organ donor''. What's it gon na be?",
#     'I told you, man! What did I say? I told you that was a dumb idea.',
#     'Come on! Just wear what you wore to school.',
#     "Why do n't you just go to your house and get your own clothes? ` Cause this is stupid.",
#     'Where the fuck is the dirt bike?',
#     "Ah, screw it. I'm just gon na kill everyone. Boom! Die, piggies!",
#     "See what my dad's got.",
#     "It's, like, 7:30 and my Mom's still here.",
#     "Fuck you, asshole. Let's just sneak down there and grab it.",
#     "I ca n't believe it. They marked them.",
#     "Shh! We. we. take some and fill it back up with water. Get ready, I'll get water.",
#     'Gin? That stuff is literally undrinkable.',
#     'Run!',
#     'Take it!',
#     'Bye, Mom! Love you.',
#     "It's fucking water!",
#     "We ca n't go back! She totally knew, she'll bust us for sure, and we have to meet Fogell.",
#     "What? It's just a vest.",
#     'Yeah, right!',
#     "You're not gon na steal it. Fogell, he's not going to steal it.",
#     "Shh. Seth's coming.",
#     'No. Shut up.',
#     'Well, here we are. Fogell, are you ready?',
#     "Goldschlager. That's for Helen, so do not forget it.",
#     "What's the difference?",
#     'Are you okay?',
#     "Seth, calm down! Fogell, stop being a baby and go buy the alcohol! You said you'd do it, so do it. It's why you bought the ID, so just go do it.",
#     'Calm down.',
#     'Did you remember a condom?',
#     'Yeah, I figured, you know, might as well. I brought one of those little things of spermicidal lube too.',
#     "It does n't mean you should n't be prepared. You did n't even bring one?",
#     "I do n't really even understand what your plan is.",
#     "Yeah, but I figured there's no harm in bringing just one little condom.",
#     "Fine. I wo n't bring the lube.",
#     'Do you think I could get Helen to do some kind of long distance thing?',
#     "I have n't seen her since she switched schools.",
#     'I heard she had breast - reduction surgery. Her tits must be crazy perfect now.',
#     'That was a waste.',
#     "I ca n't even begin to imagine the justification for making breasts smaller.",
#     "Whoa. What's this?",
#     'Check it out! The cops!',
#     'Shit! They busted Fogell!',
#     'Oh my god. Are they gon na take him downtown?',
#     'What are you talking about? Money? What about Fogell?',
#     'We have to help him!',
#     'Fine. Just. calm down. We need to think. We need to think.',
#     'What are you doing?',
#     'Whoa, whoa, whoa. Hold on. Come here.',
#     'What are you doing?',
#     "I do n't. I do n't like this idea at all. I'm just not feeling it. That guy's fucking creepy. Just look at him.",
#     "Hey, are you sure that it's cool we're here?",
#     'This is weird.',
#     "Dude, let's slip out the back.",
#     'You want to end up like that guy? Not me, I need my nuts.',
#     "You need it! I do n't need it. I'm going to tell Helen I like her, and then maybe she'll get with me ; not after I get her stinking drunk.",
#     "Because I respect her! I'm not going to put that kind of unfair pressure on her.",
#     "We're leaving, okay? These guys could kill us. You want to get killed for liquor?",
#     'Jesus.',
#     'Whaa! What the. oh.',
#     'Oh dude. Oh dude. Oh dude.',
#     'Okay. Okay. Here we go.',
#     'Helen? Helen?!?',
#     'Hey! Helen. Hi. I had bad reception. Are you at the party?',
#     'Yeah, definitely. Um, about your Goldschlager.',
#     "What's going on there?",
#     "Nope. I'm gon na be there.",
#     "I think it's going to be a real fun. event.",
#     'No. What splotch -',
#     "Oh no, that's not me either. Wrong guy, man. Sorry.",
#     "Trust me, man. That was n't me. I do n't even listen to rap.",
#     "cause, yo! Bitches and gats, bitches and gats, what do all of we's got?",
#     'When we steal all the money?',
#     'Yo! I kill the whores of Vice City with my magnum 9/Take out the punk pigs with my Glok design / Drink a fifth of Hennessy and get benign/Fuck all the bitches with their asses fine',
#     'What?',
#     'What?',
#     "No I did n't!",
#     "If you said we should burn our dicks off and I did n't, that's not bailing!",
#     'What?!',
#     'Oh! Okay! There it is! It finally comes out!',
#     "What happened to that, is that you're too stupid to get into the schools I did!",
#     "You've wasted all my time, you selfish bastard! Instead of chasing girls and making friends, I threw away the last three years talking bullshit with you! And now, because of you, I'm going to college a fucking friendless virgin!",
#     'You talking to me or yourself? You fucking loser!',
#     "I'm sorry! You pushed me first.",
#     'Nothing.',
#     'No officer. Not at all.',
#     "Puh. please do n't shoot.",
#     "Uh. I do n't know, five - foot - ten, eleven?",
#     'Oh god. Oh god. Fuck. Fuck.',
#     'Should I run!?!',
#     "We ca n't do that. He's homeless.",
#     'GOOOOOOOLDSCHLLLAAAAAAAGERRRRRRRRRR!',
#     "I ca n't believe Helen's bottle broke.",
#     "Yeah? Well, good luck getting Jule's drunk enough to have sex with you.",
#     "Fuck, Fogell! You're a god damn idiot.",
#     'Shit.',
#     'Seth, me and Fogell are rooming together next year.',
#     "I did n't tell you because -",
#     'Becca! Hey.',
#     'What?',
#     "What? What did she say? Does she think I'm a good guy? What did she say?",
#     'What?!?',
#     'Oh man. This is too much. Oh god. What do I do? I lost the Goldschlager I was supposed to bring her!',
#     'What? Oh man.',
#     "But. she's totally hammered. If I get with her, and I'm not drunk, is n't that, like, date rape?",
#     'I guess.',
#     "Calm down, Evan. She likes you. She wants to suck on your penis. That's a good thing.",
#     'Down the hatch.',
#     'Hey, Helen. Sorry I was -',
#     'Uh. well. uh.',
#     "Oh man, it's a crazy story -",
#     "I'm already pretty wasted. But. uh. here's to you.",
#     'Uh. uh. uh. you could just tell me right here -',
#     'Are you okay?',
#     "Oh man. Helen. I want to tell you, I mean, I've wanted to tell you, for a long time -",
#     'Shit. Can you, like, slip out?',
#     "Whoa. Fuckin'. careful.",
#     "You're so beautiful.",
#     "Um. thank you. I've thought you were a really incredible person for a really long time.",
#     "I'm. I'm. I'm about to. But first I just want to tell you exactly how I -",
#     "You do n't have to do that, you know, we can start this relationship on something more than just that.",
#     'Jesus Christ.',
#     "You do n't want to do this.",
#     "Look, you know I really like you, Helen, but this is. it's just too intense. And I'm so drunk I do n't even know how to, like, process -",
#     'What? Did you just call me a. pussy?',
#     'Oh god! Oh.',
#     "I'll. uh. I'll go get her. Are you going to be okay?",
#     "Life's bullshit, huh, Miroki?",
#     "Fuckin' wax off, asshole!",
#     "Fuck off, jerk! You're hurting my shoulders!",
#     "Dude! Seth! It's the cops! The cops.",
#     'Dude. You saved me!',
#     "Wan na sleep at my house, man? You're my best friend!",
#     'Yeah! Look what else I gots!',
#     'Is the bang bus anything like this?',
#     'Oh my lord. You have no idea!',
#     'And then you saved me, man! I fucking love you!',
#     "Why do n't we say that more? It feels good! I love you more than my brother, man. Like, when you went away for Easter last year, I, like, missed you. You know?",
#     "I'm sorry, man.",
#     "I need you to know that it's not like I even want to live with Fogell ; it's just that I'm really afraid of living with strangers.",
#     'Yeah, me too. Like, yeah. at least we kind of came together, again.',
#     'Good night, Seth. I love you.',
#     'Oh. uh. hey. Morning.',
#     'You sleep good?',
#     'Um.',
#     "You do n't have to. I'm not, like, doing anything.",
#     'Oh. Cool, well, can I come? I need a comforter. For college.',
#     "Do n't ask me. I do n't give a shit if your pants look good.",
#     "Fine. They're way too small.",
#     'Yeah, the male camel toe look is really big this year.',
#     'Holy shit!',
#     'Should we hide?',
#     'Helen called me a pussy to my face! What am I going to say to her?',
#     'Hi Helen, Hi Jules.',
#     'How are you feeling?',
#     'Did you have fun last night?',
#     'No, I dodged it. Whizzed right by me.',
#     'Oh! I have to get a comforter too, for college.',
#     'You could get your college pants there.',
#     'Maybe we can go eat after?',
#     'Yeah man, have a good one.']},
#   'FOGELL': {'character_name': 'FOGELL',
#    'subject_name': 'Fogell (McLovin)',
#    'subject_code': 'SB/3',
#    'rating': [23.0,
#     66.3,
#     19.0,
#     55.0,
#     81.0,
#     29.1,
#     23.9,
#     71.4,
#     46.8,
#     34.0,
#     30.4,
#     56.2,
#     80.3,
#     46.9,
#     68.6,
#     87.7,
#     62.9,
#     41.5,
#     36.4,
#     53.0,
#     62.5,
#     63.2,
#     76.0,
#     72.0,
#     33.8,
#     77.1,
#     38.0,
#     29.8,
#     30.7,
#     24.1,
#     60.9,
#     35.0,
#     26.5,
#     25.5,
#     40.5,
#     44.0,
#     43.0,
#     39.4,
#     27.6,
#     67.9,
#     75.5,
#     30.8,
#     48.0,
#     31.9,
#     43.8,
#     39.7,
#     37.4,
#     42.5,
#     64.0,
#     65.4,
#     64.8,
#     46.7,
#     56.0,
#     28.6,
#     58.5,
#     72.4,
#     74.4,
#     52.9,
#     25.2,
#     61.3,
#     60.8,
#     42.4,
#     36.2,
#     55.9,
#     57.8,
#     57.4,
#     25.8,
#     45.8,
#     66.0,
#     16.8,
#     77.2,
#     40.7,
#     20.2,
#     77.9,
#     40.7,
#     58.4,
#     5.0,
#     41.7,
#     54.5,
#     33.1,
#     42.3,
#     42.6,
#     58.3,
#     77.2,
#     52.0,
#     36.8,
#     48.9,
#     44.0,
#     39.2,
#     74.3,
#     53.0,
#     14.2,
#     43.2,
#     84.5,
#     17.9,
#     62.7,
#     52.8,
#     74.3,
#     64.9,
#     50.9,
#     48.3,
#     69.3,
#     65.9,
#     49.1,
#     40.6,
#     63.0,
#     20.3,
#     43.2,
#     69.9,
#     45.1,
#     39.2,
#     33.9,
#     53.5,
#     28.7,
#     28.8,
#     74.2,
#     78.8,
#     56.1,
#     75.4,
#     55.0,
#     56.3,
#     43.8,
#     88.9,
#     67.1,
#     79.8,
#     72.9,
#     59.3,
#     28.9,
#     24.0,
#     58.5,
#     36.8,
#     26.2,
#     26.7,
#     65.0,
#     69.1,
#     72.1,
#     40.2,
#     49.1,
#     73.8,
#     51.6,
#     66.8,
#     32.9,
#     36.2,
#     64.2,
#     40.3,
#     79.9,
#     60.4,
#     13.6,
#     52.0,
#     50.5,
#     50.9,
#     49.0,
#     51.5,
#     71.2,
#     58.0,
#     34.6,
#     71.7,
#     48.4,
#     40.1,
#     26.6,
#     76.1,
#     59.4,
#     56.0,
#     46.9,
#     55.4,
#     33.1,
#     61.9,
#     34.1,
#     38.2,
#     25.8,
#     26.0,
#     56.8,
#     29.0,
#     37.4,
#     34.9,
#     64.0,
#     55.6,
#     55.5,
#     58.3,
#     43.4,
#     61.9,
#     79.4,
#     78.9,
#     65.0,
#     38.5,
#     22.6,
#     26.2,
#     64.4,
#     61.6,
#     60.2,
#     59.4,
#     60.0,
#     54.6,
#     42.6,
#     37.9,
#     48.1,
#     48.2,
#     73.0,
#     49.5,
#     43.2,
#     33.1,
#     40.2,
#     73.2,
#     33.3,
#     32.0,
#     37.7,
#     54.8,
#     55.0,
#     46.9,
#     35.1,
#     80.9,
#     47.8,
#     64.0,
#     74.1,
#     50.3,
#     31.9,
#     40.1,
#     27.3,
#     34.0,
#     38.0,
#     63.4,
#     48.9,
#     23.0,
#     23.4,
#     81.5,
# ...
#     "So, you gon na come with me to Macy's and buy me my cover - up, or what?",
#     "I've got my dad's car. I'll take you home, and Evan can give Helen a lift.",
#     "Come on, Seth. Let's go."]},
#   'BECCA': {'character_name': 'BECCA',
#    'subject_name': 'Becca',
#    'subject_code': 'SB/5',
#    'rating': [38.0,
#     49.6,
#     28.2,
#     83.9,
#     50.4,
#     56.0,
#     41.6,
#     60.5,
#     33.8,
#     37.4,
#     37.5,
#     44.5,
#     60.4,
#     58.3,
#     42.5,
#     33.1,
#     59.1,
#     52.3,
#     51.6,
#     48.8,
#     55.2,
#     62.7,
#     37.9,
#     50.3,
#     25.7,
#     57.4,
#     48.1,
#     31.3,
#     64.7,
#     39.1,
#     64.6,
#     31.5,
#     38.4,
#     38.9,
#     39.9,
#     47.3,
#     48.5,
#     59.6,
#     42.6,
#     26.5,
#     52.7,
#     49.2,
#     44.0,
#     32.8,
#     51.1,
#     41.9,
#     49.9,
#     49.9,
#     47.5,
#     57.0,
#     48.0,
#     46.7,
#     50.2,
#     44.1,
#     45.4,
#     54.7,
#     53.1,
#     73.3,
#     48.5,
#     42.0,
#     56.7,
#     51.9,
#     37.6,
#     57.9,
#     48.0,
#     56.4,
#     60.8,
#     62.3,
#     68.1,
#     16.1,
#     49.3,
#     43.0,
#     33.4,
#     53.2,
#     58.3,
#     67.8,
#     38.6,
#     52.2,
#     56.7,
#     73.0,
#     33.7,
#     51.6,
#     46.9,
#     72.2,
#     48.3,
#     60.2,
#     65.0,
#     64.0,
#     43.1,
#     52.0,
#     53.4,
#     43.4,
#     72.9,
#     60.0,
#     50.6,
#     37.0,
#     32.4,
#     68.4,
#     57.8,
#     63.4,
#     49.6,
#     35.2,
#     45.9,
#     36.6,
#     57.0,
#     59.1,
#     32.7,
#     75.5,
#     53.4,
#     55.3,
#     56.1,
#     43.9,
#     49.0,
#     76.1,
#     52.5,
#     58.7,
#     67.8,
#     54.6,
#     72.0,
#     45.8,
#     66.2,
#     28.5,
#     69.9,
#     36.5,
#     69.7,
#     69.1,
#     44.2,
#     39.6,
#     32.2,
#     48.7,
#     34.7,
#     57.6,
#     41.9,
#     52.3,
#     38.7,
#     63.3,
#     36.7,
#     59.3,
#     61.7,
#     48.6,
#     64.5,
#     56.1,
#     47.5,
#     44.2,
#     39.0,
#     31.5,
#     53.3,
#     32.9,
#     31.6,
#     39.2,
#     46.1,
#     63.2,
#     30.2,
#     57.2,
#     35.6,
#     43.1,
#     45.7,
#     40.2,
#     45.7,
#     41.9,
#     68.6,
#     70.2,
#     52.3,
#     35.0,
#     80.7,
#     47.4,
#     37.3,
#     53.6,
#     38.9,
#     29.9,
#     38.0,
#     53.0,
#     44.7,
#     36.8,
#     24.1,
#     82.2,
#     44.7,
#     44.0,
#     62.1,
#     69.6,
#     64.4,
#     69.6,
#     70.3,
#     24.4,
#     30.4,
#     47.2,
#     50.5,
#     59.4,
#     56.1,
#     45.7,
#     38.0,
#     57.9,
#     37.0,
#     55.3,
#     36.2,
#     60.3,
#     49.5,
#     38.5,
#     40.8,
#     52.9,
#     56.5,
#     65.7,
#     60.3,
#     59.0,
#     36.7,
#     61.2,
#     55.1,
#     57.0,
#     48.4,
#     41.8,
#     64.6,
#     29.5,
#     35.9,
#     58.7,
#     57.6,
#     45.0,
#     49.0,
#     35.7,
#     41.3,
#     42.8,
#     45.4,
#     41.4,
#     39.5,
#     60.3,
#     66.3,
#     34.6,
#     71.7,
#     55.0,
#     56.2,
#     48.4,
#     60.6,
#     31.8,
#     50.7,
#     55.4,
#     45.3,
#     54.8,
#     51.1,
#     61.1,
#     55.9,
#     56.0,
#     59.1,
#     47.9,
#     52.6,
#     65.5,
#     48.1,
#     25.7,
#     34.5,
#     53.0,
#     44.1,
#     61.4,
#     48.6,
#     44.1,
#     34.8,
#     26.6,
#     56.0,
#     36.6,
#     44.7,
#     50.3,
#     71.3,
#     50.6,
#     63.6,
#     68.6,
#     55.0,
#     74.0,
#     50.0,
#     52.6,
#     59.8,
#     44.8,
#     50.4,
#     31.9,
#     73.5,
#     40.5,
#     36.1,
#     64.2,
#     53.3,
#     67.4,
#     50.4,
#     56.0,
#     48.4,
#     44.5,
#     43.0,
#     50.1,
#     53.2,
#     73.6,
#     28.5,
#     26.2,
#     47.0,
#     67.3,
#     45.2,
#     38.0,
#     46.3,
#     59.4,
#     39.3,
#     65.7,
#     53.7,
#     25.7,
#     47.4,
#     68.0,
#     59.3,
#     42.4,
#     49.9,
#     56.7,
#     59.4,
#     59.3,
#     51.2,
#     53.2,
#     33.7,
#     39.0,
#     29.8,
#     66.9,
#     53.2,
#     57.9,
#     64.2,
#     54.4,
#     72.8,
#     43.8,
#     33.1,
#     40.4,
#     42.5,
#     62.4,
#     49.9,
#     52.6,
#     54.6,
#     58.4,
#     71.8,
#     57.0,
#     49.3,
#     45.7,
#     48.7,
#     56.7,
#     52.0,
#     28.2,
#     51.4,
#     43.7,
#     76.7,
#     34.5,
#     31.2,
#     73.0,
#     51.7,
#     51.0,
#     58.3,
#     69.9,
#     45.3,
#     28.0,
#     35.1,
#     61.9,
#     45.3,
#     71.0,
#     45.9,
#     53.5,
#     58.7,
#     63.5,
#     52.2,
#     49.9,
#     68.7,
#     48.3,
#     49.7,
#     43.5,
#     54.0,
#     32.6,
#     27.6,
#     61.0,
#     39.5,
#     48.4,
#     59.8,
#     35.2,
#     74.1,
#     55.2,
#     79.6,
#     39.3,
#     55.1,
#     42.4,
#     58.2,
#     67.7,
#     25.8,
#     41.5,
#     45.0,
#     47.4,
#     58.0,
#     86.8,
#     82.4,
#     26.6,
#     55.4,
#     31.1,
#     37.1,
#     41.5,
#     60.9,
#     56.0,
#     31.5,
#     33.9,
#     35.1,
#     52.7,
#     47.7,
#     52.8,
#     58.5,
#     44.5,
#     40.3,
#     70.5,
#     40.1,
#     60.0,
#     88.1,
#     70.2,
#     17.7,
#     45.1,
#     67.5,
#     64.8,
#     60.3,
#     72.3,
#     67.3,
#     61.9,
#     65.0,
#     43.6,
#     26.6,
#     37.3,
#     73.0,
#     59.3,
#     49.5,
#     43.9,
#     23.4,
#     58.2,
#     43.5,
#     61.7,
#     42.8,
#     61.2,
#     47.0,
#     35.9,
#     31.7,
#     29.3,
#     46.5,
#     61.4,
#     18.7,
#     63.2,
#     39.9,
#     62.2,
#     71.9,
#     32.4,
#     60.0,
#     41.3,
#     42.0,
#     51.0,
#     65.0,
#     65.1,
#     41.0,
#     79.4,
#     67.0,
#     60.1,
#     56.0,
#     48.1,
#     31.9,
#     58.9,
#     71.0,
#     16.4,
#     37.9,
#     59.9,
#     70.3,
#     74.4,
#     53.2,
#     39.3,
#     33.3,
#     57.3,
#     37.6,
#     55.9,
#     36.0,
#     35.4,
#     59.4,
#     44.6,
#     55.4,
#     57.7,
#     54.3,
#     57.9,
#     54.1,
#     36.6,
#     51.4,
#     34.5,
#     63.7,
#     50.9,
#     55.0,
#     55.2,
#     70.1,
#     72.0,
#     71.3,
#     71.5,
#     40.3,
#     65.7,
#     82.3,
#     49.6,
#     56.0,
#     48.8,
#     39.8,
#     25.0,
#     57.1,
#     22.3,
#     50.9,
#     36.1,
#     39.0,
#     77.3,
#     71.4,
#     80.0,
#     32.9,
#     47.7],
#    'sentences': ['Is it him?',
#     'Where have you been, you almost blew it.',
#     "Helen. She's been waiting for you. She's right over there. She's been yammering about you all night.",
#     "It was something like, `` I'll fully blow him tonight.''",
#     "Well, Jordana stole a bottle of tequila from her parents and her and Helen have been going at it. I think she'll be fine in that department. I'd just go over there and invite her upstairs, pronto.",
#     "It's not date rape if you're drunk, too."]},
#   'OFFICER SLATER': {'character_name': 'OFFICER SLATER',
#    'subject_name': 'Officer Slater',
#    'subject_code': 'SB/6',
#    'rating': [27.2,
#     76.6,
#     33.2,
#     35.8,
#     65.9,
#     27.4,
#     61.4,
#     80.6,
#     59.9,
#     46.5,
#     56.6,
#     45.6,
#     67.6,
#     39.6,
#     76.1,
#     77.7,
#     48.1,
#     61.5,
#     40.4,
#     61.6,
#     52.1,
#     44.7,
#     62.0,
#     45.8,
#     35.0,
#     74.7,
#     22.8,
#     32.0,
#     40.8,
#     42.8,
#     46.6,
#     68.5,
#     38.3,
#     20.5,
#     33.0,
#     30.6,
#     27.1,
#     35.8,
#     40.4,
#     48.7,
#     75.8,
#     18.9,
#     39.1,
#     22.6,
#     39.6,
#     46.6,
#     28.5,
#     31.5,
#     74.7,
#     78.5,
#     71.3,
#     22.9,
#     49.5,
#     31.6,
#     64.6,
#     60.8,
#     42.0,
#     38.8,
#     25.6,
#     73.6,
#     65.5,
#     42.2,
#     55.3,
#     34.5,
#     55.4,
#     50.1,
#     24.4,
#     41.4,
#     23.5,
#     50.9,
#     61.1,
#     29.2,
#     28.5,
#     50.2,
#     26.1,
#     51.2,
#     32.4,
#     33.2,
#     51.3,
#     47.6,
#     56.1,
#     59.4,
#     64.6,
#     69.1,
#     50.7,
#     58.2,
#     22.5,
#     37.2,
#     19.7,
#     69.4,
#     50.8,
#     40.8,
#     59.2,
#     72.0,
#     21.4,
#     75.1,
#     62.0,
#     61.9,
#     66.9,
#     52.4,
#     36.8,
#     52.8,
#     65.9,
#     50.7,
#     38.9,
#     60.2,
#     40.8,
#     64.6,
#     42.0,
#     44.1,
#     68.7,
#     29.1,
#     64.2,
#     42.4,
#     46.2,
#     68.9,
#     59.0,
#     54.6,
#     58.2,
#     46.9,
#     31.1,
#     47.9,
#     53.8,
#     70.6,
#     77.7,
#     47.9,
#     61.2,
#     47.2,
#     37.7,
#     43.0,
#     52.6,
#     38.5,
#     29.2,
#     74.5,
#     76.4,
#     39.4,
#     38.6,
#     40.2,
#     49.4,
#     50.7,
#     59.5,
#     40.7,
#     34.8,
#     69.3,
#     68.9,
#     60.6,
#     78.0,
#     33.3,
#     63.7,
#     64.7,
#     37.0,
#     58.4,
#     36.5,
#     69.9,
#     64.5,
#     28.6,
#     72.3,
#     69.0,
#     27.4,
#     32.5,
#     56.7,
#     63.4,
#     71.6,
#     63.1,
#     54.2,
#     22.8,
#     73.8,
#     22.9,
#     27.2,
#     51.4,
#     33.2,
#     57.3,
#     24.1,
#     52.8,
#     40.6,
#     76.4,
#     55.1,
#     51.9,
#     54.2,
#     47.8,
#     69.4,
#     61.7,
#     62.9,
#     43.1,
#     45.2,
#     16.9,
#     35.2,
#     52.6,
#     63.4,
#     65.9,
#     63.3,
#     49.8,
#     40.8,
#     49.9,
#     55.4,
#     57.4,
#     65.8,
#     81.4,
#     78.4,
#     56.2,
#     20.0,
#     38.5,
#     63.4,
#     44.0,
#     36.2,
#     35.7,
#     50.8,
#     59.7,
#     59.7,
#     35.0,
#     63.3,
#     30.1,
#     84.4,
#     50.0,
#     48.4,
#     47.9,
#     38.0,
#     40.5,
#     35.3,
#     34.2,
#     62.2,
#     53.1,
#     39.5,
#     23.6,
#     75.1,
#     70.6,
#     49.0,
#     36.8,
#     65.4,
#     62.1,
#     63.2,
#     75.3,
#     69.0,
#     58.5,
#     56.6,
#     64.0,
#     29.5,
#     67.4,
#     69.7,
#     71.4,
#     52.0,
#     58.0,
#     62.0,
#     39.7,
#     43.4,
#     73.6,
#     75.7,
#     35.8,
#     54.4,
#     58.9,
#     62.0,
#     66.8,
#     70.8,
#     22.4,
#     46.7,
#     29.8,
#     39.9,
#     39.4,
#     65.2,
#     59.4,
#     78.3,
#     21.7,
#     52.1,
#     59.1,
#     65.5,
#     45.1,
#     53.4,
#     56.1,
#     28.8,
#     48.8,
#     65.5,
#     50.9,
#     43.9,
#     52.2,
#     80.3,
#     60.5,
#     70.7,
#     78.1,
#     51.7,
#     63.0,
#     43.4,
#     40.3,
#     38.3,
#     80.8,
#     35.1,
#     61.4,
#     40.7,
#     66.2,
#     40.2,
#     41.4,
#     70.6,
#     52.3,
#     59.0,
#     46.5,
#     66.4,
#     55.9,
#     30.8,
#     76.3,
#     58.6,
#     29.0,
#     67.5,
#     68.0,
#     32.2,
#     46.1,
#     44.9,
#     56.6,
#     42.3,
#     31.0,
#     52.9,
#     47.3,
#     28.5,
#     42.4,
#     27.4,
#     69.0,
#     38.8,
#     71.3,
#     56.3,
#     75.1,
#     59.2,
#     16.2,
#     70.8,
#     27.7,
#     35.0,
#     45.8,
#     31.8,
#     32.5,
#     16.7,
#     53.9,
#     68.8,
#     59.5,
#     24.9,
#     40.1,
#     52.0,
#     44.6,
#     29.0,
#     73.9,
#     57.2,
#     52.2,
#     41.2,
#     39.7,
#     44.5,
#     43.7,
#     58.3,
#     44.1,
#     65.8,
#     57.5,
#     36.2,
#     30.4,
#     69.8,
#     68.6,
#     63.4,
#     58.9,
#     54.8,
#     64.7,
#     56.8,
#     56.8,
#     63.2,
#     34.7,
#     72.2,
#     69.0,
#     33.8,
#     58.4,
#     49.9,
#     43.0,
#     47.2,
#     51.7,
#     56.9,
#     57.7,
#     41.3,
#     44.9,
#     56.6,
#     62.0,
#     80.8,
#     33.3,
#     55.2,
#     49.1,
#     51.1,
#     49.8,
#     76.4,
#     56.2,
#     45.9,
#     33.8,
#     40.3,
#     40.5,
#     35.6,
#     60.7,
#     37.5,
#     64.3,
#     46.9,
#     30.3,
#     69.3,
#     71.0,
#     77.4,
#     71.3,
#     52.3,
#     69.7,
#     34.9,
#     39.5,
#     19.4,
#     65.6,
#     80.7,
#     20.0,
#     33.3,
#     44.0,
#     33.6,
#     51.6,
#     49.8,
#     34.8,
#     70.0,
#     43.4,
#     57.4,
#     29.4,
#     31.3,
#     81.8,
#     77.5,
#     56.9,
#     58.0,
#     28.6,
#     44.6,
#     69.8,
#     59.8,
#     61.3,
#     41.6,
#     41.3,
#     39.0,
#     56.4,
#     27.6,
#     72.6,
#     72.9,
#     71.6,
#     30.4,
#     39.3,
#     62.7,
#     59.6,
#     81.5,
#     44.1,
#     63.2,
#     34.8,
#     30.6,
#     42.2,
#     25.4,
#     23.5,
#     74.3,
#     58.2,
#     61.8,
#     26.6,
#     41.0,
#     59.1,
#     75.3,
#     52.0,
#     36.5,
#     40.3,
#     43.4,
#     59.9,
#     44.1,
#     74.5,
#     40.6,
#     61.4,
#     48.6,
#     14.0,
#     22.8,
#     89.4,
#     67.7,
#     37.2,
#     71.6,
#     52.8,
#     62.8,
#     71.1,
#     54.3,
#     70.8,
#     83.6,
#     64.6,
#     52.9,
#     42.0,
#     66.4,
#     21.0,
#     46.6,
#     65.7,
#     63.1,
#     21.6,
#     69.1,
#     57.3,
#     50.4,
#     30.6,
#     33.3,
#     58.4,
#     53.6,
#     45.0,
#     61.6,
#     33.2,
#     59.3,
#     71.6,
#     39.0,
#     38.6,
#     52.8,
#     32.7,
#     37.8,
#     50.1,
#     77.9,
#     85.7],
#    'sentences': ['So, did he punch anyone else?',
#     "So then, son, you're the one that got punched?",
#     'MicMac what?',
#     'Cool name. And your first name?',
#     "Okay, your name is just McLovin, there's no need to get irrational.",
#     "I once arrested a man - lady who was legally named `` Pearl Necklace.''",
#     'And, how old are you McLovin?',
#     'Old enough for what?',
#     "You're an organ donor?",
#     "I did n't want to be one but my wife insisted.",
#     'Where were you going?',
#     "We'll take you there, get your information on the way. Sit tight.",
#     "Man, that lady just would n't stop crying, huh? And you're the one that got punched. Did you hear her say she has an exam tomorrow? Boo - fuckin' - hoo. Am I right?",
#     "Hah. Probably could have found a way. But a good general rule is only take people in you want to ride with. And whiny bitches do n't make that cut.",
#     "We get the gist of it. You were buying some beer, some guys came in and robbed the place. I do n't think we're gon na find ` em this time.",
#     'Only one guy? Well, fuck that. We could never catch one guy.',
#     'Yeah, McLovin. You know how many people there are in this city? I have trouble finding people I know.',
#     "Yeah, that stuff can help, but if someone walks up to me on the street, and is like, `` Hey, find Bob.'' Well, how the hell am I supposed to do that?",
#     "Exactly. If I do n't know who he is, then how am I supposed to know where he is?",
#     'Only six months in.',
#     'I got two and a half years under my belt.',
#     'Ten - four.',
#     "Nice. Ya see, Michaels, when ever there's a call for a bar, you take it.",
#     "Hey, McLovin. We got a situation at Bailey's. We have to see to that, but we'll drop you off right after. Okay?",
#     "Alright McLovin, this will only take a few minutes. Just grab a beer at the bar and we'll be done before you know it.",
#     "Alright, Michaels. I've got your back. Show this rummy how we roll.",
#     'Good one, Michaels!',
#     'Fuck!',
#     'NO!',
#     'I am buying you a beer, McLovin!',
#     "McLovin, all we do is bonk homeless people on the head. You're practically a cop now.",
#     'Oh shit.',
#     'I met the Missus at paint ball. Can you believe that? I shot her in the neck, and we just hit it off. And my first wife - who is a whore - where do you think we met? A bar.',
#     'I bet I know your trick, McLovin. You do the whole mysterious guy thing, right?',
#     'Oh! McLovin in the house!',
#     'Yeah. We got guns.',
#     'Yeah. Why not?',
#     'Here.',
#     "If you're Michaels they are. He ca n't shoot worth dick.",
#     'Only one way to settle this.',
#     "You've been saying some bold words, my friend. Better not mess up.",
#     'Yeah. Sure. Here. Go nuts.',
#     "Let's bail! Shotgun!",
#     "I wish. Probably some lame house party. We'll drop you off after. Cool?",
#     "Pretty much anything, if you're smart enough to figure it out. Like, who do you really hate? Gim me a name.",
#     'We got flashlights.',
#     "I do n't believe this is happening again.",
#     "Okay, okay, we're gon na get out of the car now. McLovin, you stay right there.",
#     "Well, you should be careful boys. That's how accidents happen.",
#     'Pardon?',
#     'Pabst. You boys been doing a bit of drinking?',
#     'Is that more beer you got over there?',
#     "Alright, Michaels. The car is completely fucked, and you're the one who fucked it up, so you've got to fix it.",
#     "We arrest these little crap stains and dump it on them, I'll take care of that. You go make sure McLovin is good to play ball. This is it, Michaels. You wan na hang with the big boys, you got ta get your hands dirty. You cool?",
#     'Get on the ground. Now! Spread your shit!',
#     'Puh - Puh - Please shut the fuck up!',
#     'How tall are you?',
#     "And you said those were `` Pumas?''",
#     'Shit! Shit! McLovin bailed!',
#     'Fuck!',
#     'Stupid little bastards.',
#     "We had a complaint about the noise. It looks like you're having a nice little party here.",
#     "Okay, everyone out. Party's over. Get out of here.",
#     "I'll go upstairs. I told you this would release some anger.",
#     'McLovin? What the fuck?',
#     'You ran away from us!',
#     'Michaels! Get up here!',
#     'McLovin!',
#     "You're going to jail, fucko.",
#     "They do n't take kindly to your type in jail, McLovin.",
#     'There you go.',
#     "Yeah! You're going to fuckin' Azkaban!",
#     "We've been fuckin' with you! Jesus! I love this kid!",
#     "We know you're not twenty five! What are we, morons? My god! What are you? Sixteen?",
#     "Alright, boys. What I'm about to show you is pretty much the greatest move in donut - spinning history. Behold : the reverse figure - eight.",
#     "Alright. I think that's all the fun we're gettin' out of this one.",
#     'and by signing this you are officially saying that as we stopped you from being mugged, a crack - head stole our cruiser and did God knows what with it.',
#     "I do n't know, can you?",
#     "I'm throwin' down the gauntlet. 50 bucks. Whoever hits the gas tank."]}}}

# %%
num_characters = 0
num_sentences = 0
num_movies = 0
movie_with_no_characters_with_more_than_100_sentences = []

for movie, data in structured_data.items():
    movie_has_more_than_100_sentences = False
    for character, char_data in data["characters"].items():
        num_characters += 1
        num_sentences += len(char_data["sentences"])
        if len(char_data["sentences"] ) >= 100:
            movie_has_more_than_100_sentences = True
    if not movie_has_more_than_100_sentences:
        print(f"Movie {movie} has no character with more than 100 sentences")
        movie_with_no_characters_with_more_than_100_sentences.append(movie)

print(f'Total number of movies: {num_movies}')
print(f'Total number of characters: {num_characters}')
print(f'Total number of sentences: {num_sentences}')
# Out:
# Movie Alien has no character with more than 100 sentences
# Movie Death Note has no character with more than 100 sentences
# Movie Bones has no character with more than 100 sentences
# Movie The Shape of Water has no character with more than 100 sentences
# Movie Ender's Game has no character with more than 100 sentences
# Movie Beauty and the Beast has no character with more than 100 sentences
# Movie Divergent has no character with more than 100 sentences
# Movie Supergirl has no character with more than 100 sentences
# Movie Raiders of the Lost Ark has no character with more than 100 sentences
# Movie The Little Mermaid has no character with more than 100 sentences
# Movie Ghostbusters has no character with more than 100 sentences
# Movie Casablanca has no character with more than 100 sentences
# Movie Hannibal has no character with more than 100 sentences
# Movie Transformers has no character with more than 100 sentences
# Movie Downton Abbey has no character with more than 100 sentences
# Movie X-Men has no character with more than 100 sentences
# Total number of movies: 0
# Total number of characters: 392
# Total number of sentences: 53179

# %%
len(movie_with_no_characters_with_more_than_100_sentences)
# Out:
# 113

# %%
new_dialogue["Alien_1979"].keys()
# Out:
# dict_keys(['ROBY', 'BROUSSARD', 'FAUST', 'MELKONIS', 'HUNTER', 'STANDARD', 'COMPUTER', 'ROBY &amp; MELKONIS'])

# %%
print("Alien" in structured_data_full)
print("Alien" in structured_data)

# For some reason, "Alien" which exist in both old_dialogue and new_dialogue
# is not in structured_data_full. 

# There might be some issues with the processing of the data.

# "Alien" exists in structured_data, but not in structured_data_full
# This is because structured_data_full only contains characters with at least 100 lines of dialogue
# Out:
# False
# True

# %%
for movie in structured_data.keys():
    if movie not in movie_in_rating_data:
        print(f"{movie} is not in moral ratings dataset")

# Since this prints none, it means all mobies in structured_data are in moral ratings dataset

# %% [markdown]
# ## Step 2

# %%
# Movies that exist in moral ratings dataset but not in structured_data
missing_movies = [movie for movie in movie_in_rating_data if movie not in structured_data.keys()]

# %%
len(missing_movies)
# Out:
# 228

# %% [markdown]
# Movies to scrape:
# - Mean Girls /
# - Robin Hood
# - The Room /
# - Ocean's 11 /
# - Lilo & Stitch /
# - Gone with the wind /
# - Tomorrow Never Dies (https://imsdb.com/scripts/Tomorrow-Never-Dies.html)
# - Zombieland /
# - Hamilton
# - Mad Max: Fury Road
# - The Devil Wears Prada (exists in old dialogue)
# - Snow White and the Seven Dwarfs (https://the-jh-movie-collection-official.fandom.com/wiki/Snow_White_and_the_Seven_Dwarfs_(1937_film)/Transcript)
# - The Notebook
# - Hamlet /
# - Fifty Shades of Grey
# - Dirty dancing (maybe)
# - Elizabethtown
# - When Harry Met Sally...
# - Brokeback Mountain
# - Roman Holiday
# - 8 Mile
# - Potrait of a Lady on Fire
# - The Spectacular Now
# - Breakfast at Tiffany's
# - Ruby Sparks
# - Moulin Rouge!
# - Amelie
# - High School Musical (Maybe)
# - Star Wars: The Last Jedi
# - The Incredibles
# - Monsters, Inc.
# - The Land Before Time (Maybe)
# - Jurassic World
# - Rogue One
# - Tangled
# - The Da Vinci Code
# - Mamma Mia!
# - Adventures of Huckleberry Finn
# - Farrenheit 451
# - Beowulf
# - Nineteen Eighty-Four
# - A Tale of Two Cities
# - After Life
# - Singin&apos; in the Rain (Singing in the rain)
# - The Scarlett Letter
# - Mrs Dalloway

# %%
for movie in missing_movies:
    print(movie)
# Out:
# Game of Thrones
# Harry Potter
# The Office
# Friends
# The West Wing
# LOST
# The Wire
# Avatar: The Last Airbender
# Star Trek: Deep Space Nine
# Pride and Prejudice
# Marvel Cinematic Universe
# The Simpsons
# That 70's Show
# Grey&apos;s Anatomy
# Breaking Bad
# Firefly + Serenity
# Lord of the Rings
# Community
# The Walking Dead
# The Big Bang Theory
# True Detective
# Parks and Recreation
# The Hunger Games
# Westworld
# Battlestar Galactica
# Mad Men
# Pirates of the Caribbean
# Sherlock
# Law & Order: SVU
# Silicon Valley
# Twin Peaks
# The X-Files
# Romeo and Juliet
# Cowboy Bebop
# Stargate SG-1
# Mean Girls
# Robin Hood
# Orange is the New Black
# Friday Night Lights
# Atlas Shrugged
# Brooklyn Nine-Nine
# The Room
# Seinfeld
# Two and Half Men
# NCIS
# This Is Us
# Arrested Development
# Ozark
# Scrubs
# Star Trek: The Next Generation
# Girls
# Prison Break
# The Mentalist
# Desperate Housewives
# The Good, the Bad, and the Ugly
# Schitt's Creek
# Glee
# House, M.D.
# The Good Place
# Chilling Adventures of Sabrina
# The 100
# Scandal
# How To Get Away With Murder
# Riverdale
# Space Force
# Gossip Girl
# Arrow
# The Umbrella Academy
# The Vampire Diaries
# CSI: Crime Scene Investigation
# Mr. Robot
# The Flash
# The Good Doctor
# Veep
# The Good Wife
# Outer Banks
# Mulan
# Killing Eve
# Castle
# Damages
# Boston Legal
# Farscape
# Ocean's 11
# The Sopranos
# How I Met Your Mother
# Lilo & Stitch
# Gone With the Wind
# Tommorrow Never Dies
# Rick and Morty
# 30 Rock
# Unbreakable Kimmy Schmidt
# Terminator 2: Judgement Day
# Zombieland
# Crazy Ex-Girlfriend
# Hamilton
# Mindhunter
# Mad Max: Fury Road
# Succession
# My Little Pony: Friendship Is Magic
# South Park
# New Girl
# Les Mis&#xE9;rables
# Gilmore Girls
# Archer
# The Devil Wears Prada
# Lucifer
# Yellowstone
# The Fall
# Pok&#xE9;mon
# Sailor Moon
# Vikings
# Entourage
# Bloodline
# Supernatural
# Finding Nemo
# Snow White and the Seven Dwarfs
# The Notebook
# It's Always Sunny in Philadelphia
# Suits
# Money Heist
# Agents of S.H.I.E.L.D.
# The Handmaid's Tale
# Once Upon a Time
# Smallville
# Outlander
# Dr. Horrible's Sing-Along Blog
# Better Call Saul
# Jane the Virgin
# Gotham
# Degrassi: The Next Generation
# Sense8
# Shameless
# Bob's Burgers
# Fleabag
# The Odyssey
# Psych
# White Collar
# Calvin and Hobbes
# Penny Arcade
# The Americans
# Stranger Things
# The Man in the High Castle
# Ctrl+Alt+Del
# Modern Family
# Dark
# Criminal Minds
# Peaky Blinders
# Sons of Anarchy
# Tropic Thunder
# The Boys
# Wynonna Earp
# Futurama
# Superstore
# Elementary
# Willy Wonka & the Chocolate Factory
# Blue Bloods
# Chicago Fire
# Hamlet
# The Blacklist
# The Queen's Gambit
# Fifty Shades of Grey
# Dirty Dancing
# Elizabethtown
# When Harry Met Sally...
# Brokeback Mountain
# ER
# Cobra Kai
# Broad City
# Roman Holiday
# 8 Mile
# Portrait of a Lady on Fire
# The Spectacular Now
# Breakfast at Tiffany's
# Ruby Sparks
# Moulin Rouge!
# Normal People
# Naruto
# Am&#xE9;lie
# High School Musical
# Ted Lasso
# Sex Education
# You
# Squid Game
# Euphoria
# Locke & Key
# Ferris Bueller&apos;s Day Off
# Star Trek: Voyager
# WandaVision
# The Crown
# Wheel of Time
# Star Wars: The Last Jedi
# Star Wars: Revenge of the Sith
# Arcane
# The Expanse
# The Witcher
# Shadow and Bone
# A Series of Unfortunate Events
# Emily in Paris
# Pretty Little Liars
# SpongeBob SquarePants
# Fullmetal Alchemist: Brotherhood
# One Punch Man
# Steins;Gate
# Attack on Titan
# Neon Genesis Evangelion
# Yellowjackets
# The Incredibles
# Monsters, Inc.
# Band of Brothers
# The Land Before Time
# Jurassic World
# Rogue One
# Tangled
# The Da Vinci Code
# Mamma Mia!
# Adventures of Huckleberry Finn
# Fahrenheit 451
# Don Quixote
# Beowulf
# Twelfth Night
# Nineteen Eighty-Four
# A Tale of Two Cities
# After Life
# Singin&apos; in the Rain
# The Scarlet Letter
# Mrs Dalloway
# The Marvelous Mrs. Maisel
# The OA
